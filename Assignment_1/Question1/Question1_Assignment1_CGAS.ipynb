# %% [markdown]
# # CGAS

# %% [markdown]
# **Question 1: Part (A)**
#
# In this section, we first use predefined search queries to extract URLs and titles of recipes from a website. This involves querying the base URL with various search terms related to ingredients and dishes. Each search term generates a list of recipe links, which are collected for further processing. Subsequently, we use these extracted URLs to retrieve detailed recipe data, which is then saved in a JSON file format. This approach ensures that we systematically gather and organize comprehensive data from the identified recipe links.

# %%
import requests
from bs4 import BeautifulSoup
from itertools import combinations
import time
import csv

# Define base URL for search
base_url = "https://www.allrecipes.com/search?q="

# Define initial search terms
search_terms = [
    "Beef", "Mutton", "Vegetables", "Chicken", "Pork", "Fish", "Shrimp", "Lamb",
    "Turkey", "Duck", "Tofu", "Cheese", "Pasta", "Rice", "Potatoes", "Eggs", "Sausage",
    "Beans", "Lentils", "Soup", "Salad", "Bread", "Noodles", "Tomatoes", "Garlic",
    "Onions", "Carrots", "Spinach", "Broccoli", "Cauliflower", "Cabbage", "Peppers",
    "Mushrooms", "Zucchini", "Squash", "Avocado", "Apples", "Oranges", "Bananas",
    "Berries", "Grapes", "Pineapple", "Mango", "Melons", "Yams", "Sweet Potatoes",
    "Corn", "Peas", "Cucumber", "Radishes", "Herbs", "Spices", "Beefsteak", "Short Ribs",
    "Filet Mignon", "Brisket", "Pork Chops", "Sausages", "Ribs", "Salmon", "Tuna",
    "Cod", "Scallops", "Crab", "Clams", "Mussels", "Oysters", "Chicken Wings",
    "Chicken Thighs", "Chicken Breasts", "Turkey Legs", "Turkey Breast", "Duck Legs",
    "Duck Breast", "Lamb Chops", "Lamb Shanks", "Mutton Chops", "Mutton Stew",
    "Tofu Stir Fry", "Cheese Sauce", "Cheese Omelette", "Pasta Salad", "Spaghetti",
    "Lasagna", "Fried Rice", "Risotto", "Potato Salad", "Mashed Potatoes", "Baked Potatoes",
    "Vegetable Soup", "Chicken Soup", "Beef Stew", "Pork Roast", "Fish Tacos",
    "Shrimp Scampi", "Tofu Curry", "Veggie Burger", "Fruit Salad", "Smoothies", "Pancakes"
]

# Function to fetch recipe links and titles from a search page
def fetch_recipe_info(search_term):
    search_url = f"{base_url}{search_term.replace(' ', '+')}"
    response = requests.get(search_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    recipes = []
    for a in soup.find_all('a', href=True):
        href = a['href']
        if '/recipe/' in href:
            full_url = f"https://www.allrecipes.com{href}"
            title_tag = a.find('span', class_='card__title-text')
            title = title_tag.get_text(strip=True) if title_tag else 'No Title'

            # Default to 'US' cuisine if not found
            cuisine = 'US'
            recipe_info = {
                'title': title,
                'link': full_url,
                'cuisine': cuisine
            }
            recipes.append(recipe_info)

    return recipes

# Function to determine cuisine
def determine_cuisine(term):
    term_lower = term.lower()
    if 'curry' in term_lower:
        return 'Asia'
    elif 'beef' in term_lower or 'taco' in term_lower or 'alfredo' in term_lower:
        return 'US'
    else:
        return 'World'

# Generate combinations of search terms
def generate_search_terms(terms, max_combination_size):
    all_combinations = []
    for r in range(1, max_combination_size + 1):
        for combo in combinations(terms, r):
            all_combinations.append(" ".join(combo))
    return all_combinations

# Main script
all_recipe_info = {}
unique_recipe_links = set()
total_recipes_found = 0
target_recipe_count = 10000  # Adjust as needed
max_no_new_recipes = 2
stop_flag = False  # Add a stop flag

# Generate combinations of search terms
search_combinations = generate_search_terms(search_terms, 3)  # Adjust max combination size as needed

# Iterate over search combinations and fetch recipes
for term in search_combinations:
    if stop_flag:  # Check if the stop flag is set to break out of the outer loop
        break

    no_new_recipes_count = 0
    while no_new_recipes_count < max_no_new_recipes:
        recipes = fetch_recipe_info(term)
        if not recipes:
            no_new_recipes_count += 1
            if no_new_recipes_count >= max_no_new_recipes:
                break
            time.sleep(1)  # Adjust sleep time as needed
            continue

        new_recipes_found = False
        for recipe in recipes:
            if recipe['link'] not in unique_recipe_links:
                recipe['cuisine'] = determine_cuisine(term)
                all_recipe_info[recipe['link']] = recipe
                unique_recipe_links.add(recipe['link'])
                total_recipes_found += 1
                new_recipes_found = True

        # Print progress
        print(f"Search term: {term}")
        print(f"Total recipes found so far: {total_recipes_found}")

        if not new_recipes_found:
            no_new_recipes_count += 1
        else:
            no_new_recipes_count = 0

        # Stop if we have enough recipes
        if total_recipes_found >= target_recipe_count:
            stop_flag = True  # Set the stop flag to break the outer loop
            break

        time.sleep(1)  # Adjust sleep time as needed

# Print final results
print(f"\nFinal Total Recipes Found: {total_recipes_found}")

# Save results to CSV
csv_file = "recipes.csv"
csv_columns = ['title', 'link', 'cuisine']
try:
    with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for recipe in all_recipe_info.values():
            writer.writerow(recipe)
    print(f"Data successfully written to {csv_file}")
except IOError:
    print("I/O error while writing to CSV")
# Out:
# Streaming output truncated to the last 5000 lines.
# Total recipes found so far: 5750
# Search term: Lamb Spinach
# Total recipes found so far: 5752
# Search term: Lamb Spinach
# Total recipes found so far: 5752
# Search term: Lamb Spinach
# Total recipes found so far: 5752
# Search term: Lamb Broccoli
# Total recipes found so far: 5753
# Search term: Lamb Broccoli
# Total recipes found so far: 5753
# Search term: Lamb Broccoli
# Total recipes found so far: 5753
# Search term: Lamb Cauliflower
# Total recipes found so far: 5755
# Search term: Lamb Cauliflower
# Total recipes found so far: 5755
# Search term: Lamb Cauliflower
# Total recipes found so far: 5755
# Search term: Lamb Cabbage
# Total recipes found so far: 5760
# Search term: Lamb Cabbage
# Total recipes found so far: 5760
# Search term: Lamb Cabbage
# Total recipes found so far: 5760
# Search term: Lamb Peppers
# Total recipes found so far: 5760
# Search term: Lamb Peppers
# Total recipes found so far: 5760
# Search term: Lamb Mushrooms
# Total recipes found so far: 5763
# Search term: Lamb Mushrooms
# Total recipes found so far: 5763
# Search term: Lamb Mushrooms
# Total recipes found so far: 5763
# Search term: Lamb Zucchini
# Total recipes found so far: 5768
# Search term: Lamb Zucchini
# Total recipes found so far: 5768
# Search term: Lamb Zucchini
# Total recipes found so far: 5768
# Search term: Lamb Squash
# Total recipes found so far: 5768
# Search term: Lamb Squash
# Total recipes found so far: 5768
# Search term: Lamb Avocado
# Total recipes found so far: 5768
# Search term: Lamb Avocado
# Total recipes found so far: 5768
# Search term: Lamb Apples
# Total recipes found so far: 5768
# Search term: Lamb Apples
# Total recipes found so far: 5768
# Search term: Lamb Oranges
# Total recipes found so far: 5771
# Search term: Lamb Oranges
# Total recipes found so far: 5771
# Search term: Lamb Oranges
# Total recipes found so far: 5771
# Search term: Lamb Bananas
# Total recipes found so far: 5771
# Search term: Lamb Bananas
# Total recipes found so far: 5771
# Search term: Lamb Berries
# Total recipes found so far: 5771
# Search term: Lamb Berries
# Total recipes found so far: 5771
# Search term: Lamb Grapes
# Total recipes found so far: 5771
# Search term: Lamb Grapes
# Total recipes found so far: 5771
# Search term: Lamb Pineapple
# Total recipes found so far: 5771
# Search term: Lamb Pineapple
# Total recipes found so far: 5771
# Search term: Lamb Mango
# Total recipes found so far: 5771
# Search term: Lamb Mango
# Total recipes found so far: 5771
# Search term: Lamb Melons
# Total recipes found so far: 5771
# Search term: Lamb Melons
# Total recipes found so far: 5771
# Search term: Lamb Yams
# Total recipes found so far: 5771
# Search term: Lamb Yams
# Total recipes found so far: 5771
# Search term: Lamb Sweet Potatoes
# Total recipes found so far: 5771
# Search term: Lamb Sweet Potatoes
# Total recipes found so far: 5771
# Search term: Lamb Corn
# Total recipes found so far: 5771
# Search term: Lamb Corn
# Total recipes found so far: 5771
# Search term: Lamb Peas
# Total recipes found so far: 5775
# Search term: Lamb Peas
# Total recipes found so far: 5775
# Search term: Lamb Peas
# Total recipes found so far: 5775
# Search term: Lamb Cucumber
# Total recipes found so far: 5779
# Search term: Lamb Cucumber
# Total recipes found so far: 5779
# Search term: Lamb Cucumber
# Total recipes found so far: 5779
# Search term: Lamb Radishes
# Total recipes found so far: 5779
# Search term: Lamb Radishes
# Total recipes found so far: 5779
# Search term: Lamb Herbs
# Total recipes found so far: 5781
# Search term: Lamb Herbs
# Total recipes found so far: 5781
# Search term: Lamb Herbs
# Total recipes found so far: 5781
# Search term: Lamb Spices
# Total recipes found so far: 5783
# Search term: Lamb Spices
# Total recipes found so far: 5783
# Search term: Lamb Spices
# Total recipes found so far: 5783
# Search term: Lamb Short Ribs
# Total recipes found so far: 5783
# Search term: Lamb Short Ribs
# Total recipes found so far: 5783
# Search term: Lamb Pork Chops
# Total recipes found so far: 5783
# Search term: Lamb Pork Chops
# Total recipes found so far: 5783
# Search term: Lamb Sausages
# Total recipes found so far: 5783
# Search term: Lamb Sausages
# Total recipes found so far: 5783
# Search term: Lamb Ribs
# Total recipes found so far: 5787
# Search term: Lamb Ribs
# Total recipes found so far: 5787
# Search term: Lamb Ribs
# Total recipes found so far: 5787
# Search term: Lamb Salmon
# Total recipes found so far: 5787
# Search term: Lamb Salmon
# Total recipes found so far: 5787
# Search term: Lamb Cod
# Total recipes found so far: 5787
# Search term: Lamb Cod
# Total recipes found so far: 5787
# Search term: Lamb Scallops
# Total recipes found so far: 5787
# Search term: Lamb Scallops
# Total recipes found so far: 5787
# Search term: Lamb Chicken Breasts
# Total recipes found so far: 5788
# Search term: Lamb Chicken Breasts
# Total recipes found so far: 5788
# Search term: Lamb Chicken Breasts
# Total recipes found so far: 5788
# Search term: Lamb Lamb Chops
# Total recipes found so far: 5788
# Search term: Lamb Lamb Chops
# Total recipes found so far: 5788
# Search term: Lamb Lamb Shanks
# Total recipes found so far: 5788
# Search term: Lamb Lamb Shanks
# Total recipes found so far: 5788
# Search term: Lamb Mutton Chops
# Total recipes found so far: 5788
# Search term: Lamb Mutton Chops
# Total recipes found so far: 5788
# Search term: Lamb Mutton Stew
# Total recipes found so far: 5788
# Search term: Lamb Mutton Stew
# Total recipes found so far: 5788
# Search term: Lamb Cheese Sauce
# Total recipes found so far: 5789
# Search term: Lamb Cheese Sauce
# Total recipes found so far: 5789
# Search term: Lamb Cheese Sauce
# Total recipes found so far: 5789
# Search term: Lamb Pasta Salad
# Total recipes found so far: 5789
# Search term: Lamb Pasta Salad
# Total recipes found so far: 5789
# Search term: Lamb Lasagna
# Total recipes found so far: 5789
# Search term: Lamb Lasagna
# Total recipes found so far: 5789
# Search term: Lamb Fried Rice
# Total recipes found so far: 5789
# Search term: Lamb Fried Rice
# Total recipes found so far: 5789
# Search term: Lamb Risotto
# Total recipes found so far: 5789
# Search term: Lamb Risotto
# Total recipes found so far: 5789
# Search term: Lamb Potato Salad
# Total recipes found so far: 5789
# Search term: Lamb Potato Salad
# Total recipes found so far: 5789
# Search term: Lamb Mashed Potatoes
# Total recipes found so far: 5790
# Search term: Lamb Mashed Potatoes
# Total recipes found so far: 5790
# Search term: Lamb Mashed Potatoes
# Total recipes found so far: 5790
# Search term: Lamb Baked Potatoes
# Total recipes found so far: 5792
# Search term: Lamb Baked Potatoes
# Total recipes found so far: 5792
# Search term: Lamb Baked Potatoes
# Total recipes found so far: 5792
# Search term: Lamb Vegetable Soup
# Total recipes found so far: 5792
# Search term: Lamb Vegetable Soup
# Total recipes found so far: 5792
# Search term: Lamb Chicken Soup
# Total recipes found so far: 5792
# Search term: Lamb Chicken Soup
# Total recipes found so far: 5792
# Search term: Lamb Beef Stew
# Total recipes found so far: 5793
# Search term: Lamb Beef Stew
# Total recipes found so far: 5793
# Search term: Lamb Beef Stew
# Total recipes found so far: 5793
# Search term: Lamb Pork Roast
# Total recipes found so far: 5795
# Search term: Lamb Pork Roast
# Total recipes found so far: 5795
# Search term: Lamb Pork Roast
# Total recipes found so far: 5795
# Search term: Lamb Veggie Burger
# Total recipes found so far: 5795
# Search term: Lamb Veggie Burger
# Total recipes found so far: 5795
# Search term: Lamb Pancakes
# Total recipes found so far: 5795
# Search term: Lamb Pancakes
# Total recipes found so far: 5795
# Search term: Turkey Duck
# Total recipes found so far: 5796
# Search term: Turkey Duck
# Total recipes found so far: 5796
# Search term: Turkey Duck
# Total recipes found so far: 5796
# Search term: Turkey Tofu
# Total recipes found so far: 5797
# Search term: Turkey Tofu
# Total recipes found so far: 5797
# Search term: Turkey Tofu
# Total recipes found so far: 5797
# Search term: Turkey Cheese
# Total recipes found so far: 5818
# Search term: Turkey Cheese
# Total recipes found so far: 5818
# Search term: Turkey Cheese
# Total recipes found so far: 5818
# Search term: Turkey Pasta
# Total recipes found so far: 5833
# Search term: Turkey Pasta
# Total recipes found so far: 5833
# Search term: Turkey Pasta
# Total recipes found so far: 5833
# Search term: Turkey Rice
# Total recipes found so far: 5846
# Search term: Turkey Rice
# Total recipes found so far: 5846
# Search term: Turkey Rice
# Total recipes found so far: 5846
# Search term: Turkey Potatoes
# Total recipes found so far: 5858
# Search term: Turkey Potatoes
# Total recipes found so far: 5858
# Search term: Turkey Potatoes
# Total recipes found so far: 5858
# Search term: Turkey Eggs
# Total recipes found so far: 5875
# Search term: Turkey Eggs
# Total recipes found so far: 5875
# Search term: Turkey Eggs
# Total recipes found so far: 5875
# Search term: Turkey Sausage
# Total recipes found so far: 5893
# Search term: Turkey Sausage
# Total recipes found so far: 5893
# Search term: Turkey Sausage
# Total recipes found so far: 5893
# Search term: Turkey Beans
# Total recipes found so far: 5912
# Search term: Turkey Beans
# Total recipes found so far: 5912
# Search term: Turkey Beans
# Total recipes found so far: 5912
# Search term: Turkey Lentils
# Total recipes found so far: 5915
# Search term: Turkey Lentils
# Total recipes found so far: 5915
# Search term: Turkey Lentils
# Total recipes found so far: 5915
# Search term: Turkey Soup
# Total recipes found so far: 5929
# Search term: Turkey Soup
# Total recipes found so far: 5929
# Search term: Turkey Soup
# Total recipes found so far: 5929
# Search term: Turkey Salad
# Total recipes found so far: 5936
# Search term: Turkey Salad
# Total recipes found so far: 5936
# Search term: Turkey Salad
# Total recipes found so far: 5936
# Search term: Turkey Bread
# Total recipes found so far: 5950
# Search term: Turkey Bread
# Total recipes found so far: 5950
# Search term: Turkey Bread
# Total recipes found so far: 5950
# Search term: Turkey Noodles
# Total recipes found so far: 5957
# Search term: Turkey Noodles
# Total recipes found so far: 5957
# Search term: Turkey Noodles
# Total recipes found so far: 5957
# Search term: Turkey Tomatoes
# Total recipes found so far: 5965
# Search term: Turkey Tomatoes
# Total recipes found so far: 5965
# Search term: Turkey Tomatoes
# Total recipes found so far: 5965
# Search term: Turkey Garlic
# Total recipes found so far: 5974
# Search term: Turkey Garlic
# Total recipes found so far: 5974
# Search term: Turkey Garlic
# Total recipes found so far: 5974
# Search term: Turkey Onions
# Total recipes found so far: 5980
# Search term: Turkey Onions
# Total recipes found so far: 5980
# Search term: Turkey Onions
# Total recipes found so far: 5980
# Search term: Turkey Carrots
# Total recipes found so far: 5985
# Search term: Turkey Carrots
# Total recipes found so far: 5985
# Search term: Turkey Carrots
# Total recipes found so far: 5985
# Search term: Turkey Spinach
# Total recipes found so far: 5993
# Search term: Turkey Spinach
# Total recipes found so far: 5993
# Search term: Turkey Spinach
# Total recipes found so far: 5993
# Search term: Turkey Broccoli
# Total recipes found so far: 6003
# Search term: Turkey Broccoli
# Total recipes found so far: 6003
# Search term: Turkey Broccoli
# Total recipes found so far: 6003
# Search term: Turkey Cauliflower
# Total recipes found so far: 6010
# Search term: Turkey Cauliflower
# Total recipes found so far: 6010
# Search term: Turkey Cauliflower
# Total recipes found so far: 6010
# Search term: Turkey Cabbage
# Total recipes found so far: 6019
# Search term: Turkey Cabbage
# Total recipes found so far: 6019
# Search term: Turkey Cabbage
# Total recipes found so far: 6019
# Search term: Turkey Peppers
# Total recipes found so far: 6024
# Search term: Turkey Peppers
# Total recipes found so far: 6024
# Search term: Turkey Peppers
# Total recipes found so far: 6024
# Search term: Turkey Mushrooms
# Total recipes found so far: 6032
# Search term: Turkey Mushrooms
# Total recipes found so far: 6032
# Search term: Turkey Mushrooms
# Total recipes found so far: 6032
# Search term: Turkey Zucchini
# Total recipes found so far: 6038
# Search term: Turkey Zucchini
# Total recipes found so far: 6038
# Search term: Turkey Zucchini
# Total recipes found so far: 6038
# Search term: Turkey Squash
# Total recipes found so far: 6045
# Search term: Turkey Squash
# Total recipes found so far: 6045
# Search term: Turkey Squash
# Total recipes found so far: 6045
# Search term: Turkey Avocado
# Total recipes found so far: 6054
# Search term: Turkey Avocado
# Total recipes found so far: 6054
# Search term: Turkey Avocado
# Total recipes found so far: 6054
# Search term: Turkey Apples
# Total recipes found so far: 6067
# Search term: Turkey Apples
# Total recipes found so far: 6067
# Search term: Turkey Apples
# Total recipes found so far: 6067
# Search term: Turkey Oranges
# Total recipes found so far: 6076
# Search term: Turkey Oranges
# Total recipes found so far: 6076
# Search term: Turkey Oranges
# Total recipes found so far: 6076
# Search term: Turkey Bananas
# Total recipes found so far: 6077
# Search term: Turkey Bananas
# Total recipes found so far: 6077
# Search term: Turkey Bananas
# Total recipes found so far: 6077
# Search term: Turkey Berries
# Total recipes found so far: 6085
# Search term: Turkey Berries
# Total recipes found so far: 6085
# Search term: Turkey Berries
# Total recipes found so far: 6085
# Search term: Turkey Grapes
# Total recipes found so far: 6088
# Search term: Turkey Grapes
# Total recipes found so far: 6088
# Search term: Turkey Grapes
# Total recipes found so far: 6088
# Search term: Turkey Pineapple
# Total recipes found so far: 6093
# Search term: Turkey Pineapple
# Total recipes found so far: 6093
# Search term: Turkey Pineapple
# Total recipes found so far: 6093
# Search term: Turkey Mango
# Total recipes found so far: 6096
# Search term: Turkey Mango
# Total recipes found so far: 6096
# Search term: Turkey Mango
# Total recipes found so far: 6096
# Search term: Turkey Yams
# Total recipes found so far: 6097
# Search term: Turkey Yams
# Total recipes found so far: 6097
# Search term: Turkey Yams
# Total recipes found so far: 6097
# Search term: Turkey Sweet Potatoes
# Total recipes found so far: 6100
# Search term: Turkey Sweet Potatoes
# Total recipes found so far: 6100
# Search term: Turkey Sweet Potatoes
# Total recipes found so far: 6100
# Search term: Turkey Corn
# Total recipes found so far: 6106
# Search term: Turkey Corn
# Total recipes found so far: 6106
# Search term: Turkey Corn
# Total recipes found so far: 6106
# Search term: Turkey Peas
# Total recipes found so far: 6110
# Search term: Turkey Peas
# Total recipes found so far: 6110
# Search term: Turkey Peas
# Total recipes found so far: 6110
# Search term: Turkey Cucumber
# Total recipes found so far: 6111
# Search term: Turkey Cucumber
# Total recipes found so far: 6111
# Search term: Turkey Cucumber
# Total recipes found so far: 6111
# Search term: Turkey Radishes
# Total recipes found so far: 6111
# Search term: Turkey Radishes
# Total recipes found so far: 6111
# Search term: Turkey Herbs
# Total recipes found so far: 6113
# Search term: Turkey Herbs
# Total recipes found so far: 6113
# Search term: Turkey Herbs
# Total recipes found so far: 6113
# Search term: Turkey Spices
# Total recipes found so far: 6117
# Search term: Turkey Spices
# Total recipes found so far: 6117
# Search term: Turkey Spices
# Total recipes found so far: 6117
# Search term: Turkey Pork Chops
# Total recipes found so far: 6120
# Search term: Turkey Pork Chops
# Total recipes found so far: 6120
# Search term: Turkey Pork Chops
# Total recipes found so far: 6120
# Search term: Turkey Sausages
# Total recipes found so far: 6120
# Search term: Turkey Sausages
# Total recipes found so far: 6120
# Search term: Turkey Ribs
# Total recipes found so far: 6125
# Search term: Turkey Ribs
# Total recipes found so far: 6125
# Search term: Turkey Ribs
# Total recipes found so far: 6125
# Search term: Turkey Salmon
# Total recipes found so far: 6127
# Search term: Turkey Salmon
# Total recipes found so far: 6127
# Search term: Turkey Salmon
# Total recipes found so far: 6127
# Search term: Turkey Tuna
# Total recipes found so far: 6127
# Search term: Turkey Tuna
# Total recipes found so far: 6127
# Search term: Turkey Crab
# Total recipes found so far: 6127
# Search term: Turkey Crab
# Total recipes found so far: 6127
# Search term: Turkey Clams
# Total recipes found so far: 6127
# Search term: Turkey Clams
# Total recipes found so far: 6127
# Search term: Turkey Oysters
# Total recipes found so far: 6130
# Search term: Turkey Oysters
# Total recipes found so far: 6130
# Search term: Turkey Oysters
# Total recipes found so far: 6130
# Search term: Turkey Chicken Wings
# Total recipes found so far: 6130
# Search term: Turkey Chicken Wings
# Total recipes found so far: 6130
# Search term: Turkey Chicken Thighs
# Total recipes found so far: 6137
# Search term: Turkey Chicken Thighs
# Total recipes found so far: 6137
# Search term: Turkey Chicken Thighs
# Total recipes found so far: 6137
# Search term: Turkey Chicken Breasts
# Total recipes found so far: 6138
# Search term: Turkey Chicken Breasts
# Total recipes found so far: 6138
# Search term: Turkey Chicken Breasts
# Total recipes found so far: 6138
# Search term: Turkey Turkey Legs
# Total recipes found so far: 6140
# Search term: Turkey Turkey Legs
# Total recipes found so far: 6140
# Search term: Turkey Turkey Legs
# Total recipes found so far: 6140
# Search term: Turkey Turkey Breast
# Total recipes found so far: 6142
# Search term: Turkey Turkey Breast
# Total recipes found so far: 6142
# Search term: Turkey Turkey Breast
# Total recipes found so far: 6142
# Search term: Turkey Duck Legs
# Total recipes found so far: 6142
# Search term: Turkey Duck Legs
# Total recipes found so far: 6142
# Search term: Turkey Duck Breast
# Total recipes found so far: 6142
# Search term: Turkey Duck Breast
# Total recipes found so far: 6142
# Search term: Turkey Lamb Chops
# Total recipes found so far: 6142
# Search term: Turkey Lamb Chops
# Total recipes found so far: 6142
# Search term: Turkey Tofu Stir Fry
# Total recipes found so far: 6142
# Search term: Turkey Tofu Stir Fry
# Total recipes found so far: 6142
# Search term: Turkey Cheese Sauce
# Total recipes found so far: 6145
# Search term: Turkey Cheese Sauce
# Total recipes found so far: 6145
# Search term: Turkey Cheese Sauce
# Total recipes found so far: 6145
# Search term: Turkey Cheese Omelette
# Total recipes found so far: 6145
# Search term: Turkey Cheese Omelette
# Total recipes found so far: 6145
# Search term: Turkey Pasta Salad
# Total recipes found so far: 6146
# Search term: Turkey Pasta Salad
# Total recipes found so far: 6146
# Search term: Turkey Pasta Salad
# Total recipes found so far: 6146
# Search term: Turkey Spaghetti
# Total recipes found so far: 6153
# Search term: Turkey Spaghetti
# Total recipes found so far: 6153
# Search term: Turkey Spaghetti
# Total recipes found so far: 6153
# Search term: Turkey Lasagna
# Total recipes found so far: 6160
# Search term: Turkey Lasagna
# Total recipes found so far: 6160
# Search term: Turkey Lasagna
# Total recipes found so far: 6160
# Search term: Turkey Fried Rice
# Total recipes found so far: 6161
# Search term: Turkey Fried Rice
# Total recipes found so far: 6161
# Search term: Turkey Fried Rice
# Total recipes found so far: 6161
# Search term: Turkey Risotto
# Total recipes found so far: 6161
# Search term: Turkey Risotto
# Total recipes found so far: 6161
# Search term: Turkey Potato Salad
# Total recipes found so far: 6162
# Search term: Turkey Potato Salad
# Total recipes found so far: 6162
# Search term: Turkey Potato Salad
# Total recipes found so far: 6162
# Search term: Turkey Mashed Potatoes
# Total recipes found so far: 6164
# Search term: Turkey Mashed Potatoes
# Total recipes found so far: 6164
# Search term: Turkey Mashed Potatoes
# Total recipes found so far: 6164
# Search term: Turkey Baked Potatoes
# Total recipes found so far: 6167
# Search term: Turkey Baked Potatoes
# Total recipes found so far: 6167
# Search term: Turkey Baked Potatoes
# Total recipes found so far: 6167
# Search term: Turkey Vegetable Soup
# Total recipes found so far: 6168
# Search term: Turkey Vegetable Soup
# Total recipes found so far: 6168
# Search term: Turkey Vegetable Soup
# Total recipes found so far: 6168
# Search term: Turkey Chicken Soup
# Total recipes found so far: 6169
# Search term: Turkey Chicken Soup
# Total recipes found so far: 6169
# Search term: Turkey Chicken Soup
# Total recipes found so far: 6169
# Search term: Turkey Beef Stew
# Total recipes found so far: 6171
# Search term: Turkey Beef Stew
# Total recipes found so far: 6171
# Search term: Turkey Beef Stew
# Total recipes found so far: 6171
# Search term: Turkey Pork Roast
# Total recipes found so far: 6172
# Search term: Turkey Pork Roast
# Total recipes found so far: 6172
# Search term: Turkey Pork Roast
# Total recipes found so far: 6172
# Search term: Turkey Veggie Burger
# Total recipes found so far: 6172
# Search term: Turkey Veggie Burger
# Total recipes found so far: 6172
# Search term: Turkey Fruit Salad
# Total recipes found so far: 6173
# Search term: Turkey Fruit Salad
# Total recipes found so far: 6173
# Search term: Turkey Fruit Salad
# Total recipes found so far: 6173
# Search term: Turkey Smoothies
# Total recipes found so far: 6173
# Search term: Turkey Smoothies
# Total recipes found so far: 6173
# Search term: Turkey Pancakes
# Total recipes found so far: 6174
# Search term: Turkey Pancakes
# Total recipes found so far: 6174
# Search term: Turkey Pancakes
# Total recipes found so far: 6174
# Search term: Duck Tofu
# Total recipes found so far: 6174
# Search term: Duck Tofu
# Total recipes found so far: 6174
# Search term: Duck Cheese
# Total recipes found so far: 6176
# Search term: Duck Cheese
# Total recipes found so far: 6176
# Search term: Duck Cheese
# Total recipes found so far: 6176
# Search term: Duck Rice
# Total recipes found so far: 6176
# Search term: Duck Rice
# Total recipes found so far: 6176
# Search term: Duck Potatoes
# Total recipes found so far: 6177
# Search term: Duck Potatoes
# Total recipes found so far: 6177
# Search term: Duck Potatoes
# Total recipes found so far: 6177
# Search term: Duck Eggs
# Total recipes found so far: 6178
# Search term: Duck Eggs
# Total recipes found so far: 6178
# Search term: Duck Eggs
# Total recipes found so far: 6178
# Search term: Duck Sausage
# Total recipes found so far: 6178
# Search term: Duck Sausage
# Total recipes found so far: 6178
# Search term: Duck Beans
# Total recipes found so far: 6178
# Search term: Duck Beans
# Total recipes found so far: 6178
# Search term: Duck Soup
# Total recipes found so far: 6178
# Search term: Duck Soup
# Total recipes found so far: 6178
# Search term: Duck Salad
# Total recipes found so far: 6178
# Search term: Duck Salad
# Total recipes found so far: 6178
# Search term: Duck Bread
# Total recipes found so far: 6178
# Search term: Duck Bread
# Total recipes found so far: 6178
# Search term: Duck Noodles
# Total recipes found so far: 6178
# Search term: Duck Noodles
# Total recipes found so far: 6178
# Search term: Duck Tomatoes
# Total recipes found so far: 6178
# Search term: Duck Tomatoes
# Total recipes found so far: 6178
# Search term: Duck Garlic
# Total recipes found so far: 6178
# Search term: Duck Garlic
# Total recipes found so far: 6178
# Search term: Duck Onions
# Total recipes found so far: 6179
# Search term: Duck Onions
# Total recipes found so far: 6179
# Search term: Duck Onions
# Total recipes found so far: 6179
# Search term: Duck Carrots
# Total recipes found so far: 6179
# Search term: Duck Carrots
# Total recipes found so far: 6179
# Search term: Duck Broccoli
# Total recipes found so far: 6179
# Search term: Duck Broccoli
# Total recipes found so far: 6179
# Search term: Duck Cabbage
# Total recipes found so far: 6179
# Search term: Duck Cabbage
# Total recipes found so far: 6179
# Search term: Duck Peppers
# Total recipes found so far: 6179
# Search term: Duck Peppers
# Total recipes found so far: 6179
# Search term: Duck Mushrooms
# Total recipes found so far: 6179
# Search term: Duck Mushrooms
# Total recipes found so far: 6179
# Search term: Duck Apples
# Total recipes found so far: 6180
# Search term: Duck Apples
# Total recipes found so far: 6180
# Search term: Duck Apples
# Total recipes found so far: 6180
# Search term: Duck Oranges
# Total recipes found so far: 6180
# Search term: Duck Oranges
# Total recipes found so far: 6180
# Search term: Duck Berries
# Total recipes found so far: 6180
# Search term: Duck Berries
# Total recipes found so far: 6180
# Search term: Duck Pineapple
# Total recipes found so far: 6182
# Search term: Duck Pineapple
# Total recipes found so far: 6182
# Search term: Duck Pineapple
# Total recipes found so far: 6182
# Search term: Duck Mango
# Total recipes found so far: 6182
# Search term: Duck Mango
# Total recipes found so far: 6182
# Search term: Duck Corn
# Total recipes found so far: 6182
# Search term: Duck Corn
# Total recipes found so far: 6182
# Search term: Duck Cucumber
# Total recipes found so far: 6182
# Search term: Duck Cucumber
# Total recipes found so far: 6182
# Search term: Duck Herbs
# Total recipes found so far: 6182
# Search term: Duck Herbs
# Total recipes found so far: 6182
# Search term: Duck Spices
# Total recipes found so far: 6182
# Search term: Duck Spices
# Total recipes found so far: 6182
# Search term: Duck Pork Chops
# Total recipes found so far: 6182
# Search term: Duck Pork Chops
# Total recipes found so far: 6182
# Search term: Duck Sausages
# Total recipes found so far: 6182
# Search term: Duck Sausages
# Total recipes found so far: 6182
# Search term: Duck Ribs
# Total recipes found so far: 6182
# Search term: Duck Ribs
# Total recipes found so far: 6182
# Search term: Duck Salmon
# Total recipes found so far: 6182
# Search term: Duck Salmon
# Total recipes found so far: 6182
# Search term: Duck Mussels
# Total recipes found so far: 6182
# Search term: Duck Mussels
# Total recipes found so far: 6182
# Search term: Duck Oysters
# Total recipes found so far: 6182
# Search term: Duck Oysters
# Total recipes found so far: 6182
# Search term: Duck Chicken Wings
# Total recipes found so far: 6182
# Search term: Duck Chicken Wings
# Total recipes found so far: 6182
# Search term: Duck Chicken Thighs
# Total recipes found so far: 6182
# Search term: Duck Chicken Thighs
# Total recipes found so far: 6182
# Search term: Duck Chicken Breasts
# Total recipes found so far: 6182
# Search term: Duck Chicken Breasts
# Total recipes found so far: 6182
# Search term: Duck Turkey Legs
# Total recipes found so far: 6182
# Search term: Duck Turkey Legs
# Total recipes found so far: 6182
# Search term: Duck Turkey Breast
# Total recipes found so far: 6182
# Search term: Duck Turkey Breast
# Total recipes found so far: 6182
# Search term: Duck Duck Legs
# Total recipes found so far: 6182
# Search term: Duck Duck Legs
# Total recipes found so far: 6182
# Search term: Duck Duck Breast
# Total recipes found so far: 6182
# Search term: Duck Duck Breast
# Total recipes found so far: 6182
# Search term: Duck Lamb Chops
# Total recipes found so far: 6182
# Search term: Duck Lamb Chops
# Total recipes found so far: 6182
# Search term: Duck Cheese Sauce
# Total recipes found so far: 6182
# Search term: Duck Cheese Sauce
# Total recipes found so far: 6182
# Search term: Duck Fried Rice
# Total recipes found so far: 6182
# Search term: Duck Fried Rice
# Total recipes found so far: 6182
# Search term: Duck Baked Potatoes
# Total recipes found so far: 6182
# Search term: Duck Baked Potatoes
# Total recipes found so far: 6182
# Search term: Duck Vegetable Soup
# Total recipes found so far: 6182
# Search term: Duck Vegetable Soup
# Total recipes found so far: 6182
# Search term: Duck Chicken Soup
# Total recipes found so far: 6182
# Search term: Duck Chicken Soup
# Total recipes found so far: 6182
# Search term: Duck Pork Roast
# Total recipes found so far: 6182
# Search term: Duck Pork Roast
# Total recipes found so far: 6182
# Search term: Duck Pancakes
# Total recipes found so far: 6182
# Search term: Duck Pancakes
# Total recipes found so far: 6182
# Search term: Tofu Cheese
# Total recipes found so far: 6195
# Search term: Tofu Cheese
# Total recipes found so far: 6195
# Search term: Tofu Cheese
# Total recipes found so far: 6195
# Search term: Tofu Pasta
# Total recipes found so far: 6201
# Search term: Tofu Pasta
# Total recipes found so far: 6201
# Search term: Tofu Pasta
# Total recipes found so far: 6201
# Search term: Tofu Rice
# Total recipes found so far: 6207
# Search term: Tofu Rice
# Total recipes found so far: 6207
# Total recipes found so far: 6268
# Search term: Tofu Zucchini
# Total recipes found so far: 6270
# Search term: Tofu Zucchini
# Total recipes found so far: 6270
# Search term: Tofu Zucchini
# Total recipes found so far: 6270
# Search term: Tofu Squash
# Total recipes found so far: 6274
# Search term: Tofu Squash
# Total recipes found so far: 6274
# Search term: Tofu Squash
# Total recipes found so far: 6274
# Search term: Tofu Avocado
# Total recipes found so far: 6277
# Search term: Tofu Avocado
# Total recipes found so far: 6277
# Search term: Tofu Avocado
# Total recipes found so far: 6277
# Search term: Tofu Apples
# Total recipes found so far: 6278
# Search term: Tofu Apples
# Total recipes found so far: 6278
# Search term: Tofu Apples
# Total recipes found so far: 6278
# Search term: Tofu Oranges
# Total recipes found so far: 6281
# Search term: Tofu Oranges
# Total recipes found so far: 6281
# Search term: Tofu Oranges
# Total recipes found so far: 6281
# Search term: Tofu Bananas
# Total recipes found so far: 6283
# Search term: Tofu Bananas
# Total recipes found so far: 6283
# Search term: Tofu Bananas
# Total recipes found so far: 6283
# Search term: Tofu Berries
# Total recipes found so far: 6284
# Search term: Tofu Berries
# Total recipes found so far: 6284
# Search term: Tofu Berries
# Total recipes found so far: 6284
# Search term: Tofu Grapes
# Total recipes found so far: 6285
# Search term: Tofu Grapes
# Total recipes found so far: 6285
# Search term: Tofu Grapes
# Total recipes found so far: 6285
# Search term: Tofu Pineapple
# Total recipes found so far: 6287
# Search term: Tofu Pineapple
# Total recipes found so far: 6287
# Search term: Tofu Pineapple
# Total recipes found so far: 6287
# Search term: Tofu Mango
# Total recipes found so far: 6288
# Search term: Tofu Mango
# Total recipes found so far: 6288
# Search term: Tofu Mango
# Total recipes found so far: 6288
# Search term: Tofu Yams
# Total recipes found so far: 6288
# Search term: Tofu Yams
# Total recipes found so far: 6288
# Search term: Tofu Sweet Potatoes
# Total recipes found so far: 6288
# Search term: Tofu Sweet Potatoes
# Total recipes found so far: 6288
# Search term: Tofu Corn
# Total recipes found so far: 6291
# Search term: Tofu Corn
# Total recipes found so far: 6291
# Search term: Tofu Corn
# Total recipes found so far: 6291
# Search term: Tofu Peas
# Total recipes found so far: 6291
# Search term: Tofu Peas
# Total recipes found so far: 6291
# Search term: Tofu Cucumber
# Total recipes found so far: 6292
# Search term: Tofu Cucumber
# Total recipes found so far: 6292
# Search term: Tofu Cucumber
# Total recipes found so far: 6292
# Search term: Tofu Radishes
# Total recipes found so far: 6292
# Search term: Tofu Radishes
# Total recipes found so far: 6292
# Search term: Tofu Herbs
# Total recipes found so far: 6293
# Search term: Tofu Herbs
# Total recipes found so far: 6293
# Search term: Tofu Herbs
# Total recipes found so far: 6293
# Search term: Tofu Spices
# Total recipes found so far: 6293
# Search term: Tofu Spices
# Total recipes found so far: 6293
# Search term: Tofu Pork Chops
# Total recipes found so far: 6293
# Search term: Tofu Pork Chops
# Total recipes found so far: 6293
# Search term: Tofu Sausages
# Total recipes found so far: 6293
# Search term: Tofu Sausages
# Total recipes found so far: 6293
# Search term: Tofu Salmon
# Total recipes found so far: 6294
# Search term: Tofu Salmon
# Total recipes found so far: 6294
# Search term: Tofu Salmon
# Total recipes found so far: 6294
# Search term: Tofu Tuna
# Total recipes found so far: 6294
# Search term: Tofu Tuna
# Total recipes found so far: 6294
# Search term: Tofu Crab
# Total recipes found so far: 6294
# Search term: Tofu Crab
# Total recipes found so far: 6294
# Search term: Tofu Clams
# Total recipes found so far: 6294
# Search term: Tofu Clams
# Total recipes found so far: 6294
# Search term: Tofu Oysters
# Total recipes found so far: 6298
# Search term: Tofu Oysters
# Total recipes found so far: 6298
# Search term: Tofu Oysters
# Total recipes found so far: 6298
# Search term: Tofu Chicken Thighs
# Total recipes found so far: 6298
# Search term: Tofu Chicken Thighs
# Total recipes found so far: 6298
# Search term: Tofu Chicken Breasts
# Total recipes found so far: 6298
# Search term: Tofu Chicken Breasts
# Total recipes found so far: 6298
# Search term: Tofu Tofu Stir Fry
# Total recipes found so far: 6299
# Search term: Tofu Tofu Stir Fry
# Total recipes found so far: 6299
# Search term: Tofu Tofu Stir Fry
# Total recipes found so far: 6299
# Search term: Tofu Cheese Sauce
# Total recipes found so far: 6301
# Search term: Tofu Cheese Sauce
# Total recipes found so far: 6301
# Search term: Tofu Cheese Sauce
# Total recipes found so far: 6301
# Search term: Tofu Pasta Salad
# Total recipes found so far: 6301
# Search term: Tofu Pasta Salad
# Total recipes found so far: 6301
# Search term: Tofu Spaghetti
# Total recipes found so far: 6301
# Search term: Tofu Spaghetti
# Total recipes found so far: 6301
# Search term: Tofu Lasagna
# Total recipes found so far: 6301
# Search term: Tofu Lasagna
# Total recipes found so far: 6301
# Search term: Tofu Fried Rice
# Total recipes found so far: 6301
# Search term: Tofu Fried Rice
# Total recipes found so far: 6301
# Search term: Tofu Baked Potatoes
# Total recipes found so far: 6301
# Search term: Tofu Baked Potatoes
# Total recipes found so far: 6301
# Search term: Tofu Vegetable Soup
# Total recipes found so far: 6303
# Search term: Tofu Vegetable Soup
# Total recipes found so far: 6303
# Search term: Tofu Vegetable Soup
# Total recipes found so far: 6303
# Search term: Tofu Chicken Soup
# Total recipes found so far: 6304
# Search term: Tofu Chicken Soup
# Total recipes found so far: 6304
# Search term: Tofu Chicken Soup
# Total recipes found so far: 6304
# Search term: Tofu Beef Stew
# Total recipes found so far: 6304
# Search term: Tofu Beef Stew
# Total recipes found so far: 6304
# Search term: Tofu Tofu Curry
# Total recipes found so far: 6304
# Search term: Tofu Tofu Curry
# Total recipes found so far: 6304
# Search term: Tofu Smoothies
# Total recipes found so far: 6306
# Search term: Tofu Smoothies
# Total recipes found so far: 6306
# Search term: Tofu Smoothies
# Total recipes found so far: 6306
# Search term: Tofu Pancakes
# Total recipes found so far: 6306
# Search term: Tofu Pancakes
# Total recipes found so far: 6306
# Search term: Cheese Pasta
# Total recipes found so far: 6319
# Search term: Cheese Pasta
# Total recipes found so far: 6319
# Search term: Cheese Pasta
# Total recipes found so far: 6319
# Search term: Cheese Rice
# Total recipes found so far: 6335
# Search term: Cheese Rice
# Total recipes found so far: 6335
# Total recipes found so far: 6594
# Search term: Cheese Mushrooms
# Total recipes found so far: 6607
# Search term: Cheese Mushrooms
# Total recipes found so far: 6607
# Search term: Cheese Mushrooms
# Total recipes found so far: 6607
# Search term: Cheese Zucchini
# Total recipes found so far: 6616
# Search term: Cheese Zucchini
# Total recipes found so far: 6616
# Search term: Cheese Zucchini
# Total recipes found so far: 6616
# Search term: Cheese Squash
# Total recipes found so far: 6630
# Search term: Cheese Squash
# Total recipes found so far: 6630
# Search term: Cheese Squash
# Total recipes found so far: 6630
# Search term: Cheese Avocado
# Total recipes found so far: 6642
# Search term: Cheese Avocado
# Total recipes found so far: 6642
# Search term: Cheese Avocado
# Total recipes found so far: 6642
# Search term: Cheese Apples
# Total recipes found so far: 6657
# Search term: Cheese Apples
# Total recipes found so far: 6657
# Search term: Cheese Apples
# Total recipes found so far: 6657
# Search term: Cheese Oranges
# Total recipes found so far: 6669
# Search term: Cheese Oranges
# Total recipes found so far: 6669
# Search term: Cheese Oranges
# Total recipes found so far: 6669
# Search term: Cheese Bananas
# Total recipes found so far: 6683
# Search term: Cheese Bananas
# Total recipes found so far: 6683
# Search term: Cheese Bananas
# Total recipes found so far: 6683
# Search term: Cheese Berries
# Total recipes found so far: 6690
# Search term: Cheese Berries
# Total recipes found so far: 6690
# Search term: Cheese Berries
# Total recipes found so far: 6690
# Search term: Cheese Grapes
# Total recipes found so far: 6701
# Search term: Cheese Grapes
# Total recipes found so far: 6701
# Search term: Cheese Grapes
# Total recipes found so far: 6701
# Search term: Cheese Pineapple
# Total recipes found so far: 6716
# Search term: Cheese Pineapple
# Total recipes found so far: 6716
# Search term: Cheese Pineapple
# Total recipes found so far: 6716
# Search term: Cheese Mango
# Total recipes found so far: 6727
# Search term: Cheese Mango
# Total recipes found so far: 6727
# Search term: Cheese Mango
# Total recipes found so far: 6727
# Search term: Cheese Melons
# Total recipes found so far: 6732
# Search term: Cheese Melons
# Total recipes found so far: 6732
# Search term: Cheese Melons
# Total recipes found so far: 6732
# Search term: Cheese Yams
# Total recipes found so far: 6735
# Search term: Cheese Yams
# Total recipes found so far: 6735
# Search term: Cheese Yams
# Total recipes found so far: 6735
# Search term: Cheese Sweet Potatoes
# Total recipes found so far: 6750
# Search term: Cheese Sweet Potatoes
# Total recipes found so far: 6750
# Search term: Cheese Sweet Potatoes
# Total recipes found so far: 6750
# Search term: Cheese Corn
# Total recipes found so far: 6765
# Search term: Cheese Corn
# Total recipes found so far: 6765
# Search term: Cheese Corn
# Total recipes found so far: 6765
# Search term: Cheese Peas
# Total recipes found so far: 6777
# Search term: Cheese Peas
# Total recipes found so far: 6777
# Search term: Cheese Peas
# Total recipes found so far: 6777
# Search term: Cheese Cucumber
# Total recipes found so far: 6794
# Search term: Cheese Cucumber
# Total recipes found so far: 6794
# Search term: Cheese Cucumber
# Total recipes found so far: 6794
# Search term: Cheese Radishes
# Total recipes found so far: 6804
# Search term: Cheese Radishes
# Total recipes found so far: 6804
# Search term: Cheese Radishes
# Total recipes found so far: 6804
# Search term: Cheese Herbs
# Total recipes found so far: 6811
# Search term: Cheese Herbs
# Total recipes found so far: 6811
# Search term: Cheese Herbs
# Total recipes found so far: 6811
# Search term: Cheese Spices
# Total recipes found so far: 6820
# Search term: Cheese Spices
# Total recipes found so far: 6820
# Search term: Cheese Spices
# Total recipes found so far: 6820
# Search term: Cheese Short Ribs
# Total recipes found so far: 6823
# Search term: Cheese Short Ribs
# Total recipes found so far: 6823
# Search term: Cheese Short Ribs
# Total recipes found so far: 6823
# Search term: Cheese Filet Mignon
# Total recipes found so far: 6826
# Search term: Cheese Filet Mignon
# Total recipes found so far: 6826
# Search term: Cheese Filet Mignon
# Total recipes found so far: 6826
# Search term: Cheese Brisket
# Total recipes found so far: 6827
# Search term: Cheese Brisket
# Total recipes found so far: 6827
# Search term: Cheese Brisket
# Total recipes found so far: 6827
# Search term: Cheese Pork Chops
# Total recipes found so far: 6830
# Search term: Cheese Pork Chops
# Total recipes found so far: 6830
# Search term: Cheese Pork Chops
# Total recipes found so far: 6830
# Search term: Cheese Sausages
# Total recipes found so far: 6835
# Search term: Cheese Sausages
# Total recipes found so far: 6835
# Search term: Cheese Sausages
# Total recipes found so far: 6835
# Search term: Cheese Ribs
# Total recipes found so far: 6844
# Search term: Cheese Ribs
# Total recipes found so far: 6844
# Search term: Cheese Ribs
# Total recipes found so far: 6844
# Search term: Cheese Salmon
# Total recipes found so far: 6863
# Search term: Cheese Salmon
# Total recipes found so far: 6863
# Search term: Cheese Salmon
# Total recipes found so far: 6863
# Search term: Cheese Tuna
# Total recipes found so far: 6877
# Search term: Cheese Tuna
# Total recipes found so far: 6877
# Search term: Cheese Tuna
# Total recipes found so far: 6877
# Search term: Cheese Cod
# Total recipes found so far: 6879
# Search term: Cheese Cod
# Total recipes found so far: 6879
# Search term: Cheese Cod
# Total recipes found so far: 6879
# Search term: Cheese Scallops
# Total recipes found so far: 6883
# Search term: Cheese Scallops
# Total recipes found so far: 6883
# Search term: Cheese Scallops
# Total recipes found so far: 6883
# Search term: Cheese Crab
# Total recipes found so far: 6894
# Search term: Cheese Crab
# Total recipes found so far: 6894
# Search term: Cheese Crab
# Total recipes found so far: 6894
# Search term: Cheese Clams
# Total recipes found so far: 6904
# Search term: Cheese Clams
# Total recipes found so far: 6904
# Search term: Cheese Clams
# Total recipes found so far: 6904
# Search term: Cheese Mussels
# Total recipes found so far: 6904
# Search term: Cheese Mussels
# Total recipes found so far: 6904
# Search term: Cheese Oysters
# Total recipes found so far: 6912
# Search term: Cheese Oysters
# Total recipes found so far: 6912
# Search term: Cheese Oysters
# Total recipes found so far: 6912
# Search term: Cheese Chicken Wings
# Total recipes found so far: 6921
# Search term: Cheese Chicken Wings
# Total recipes found so far: 6921
# Search term: Cheese Chicken Wings
# Total recipes found so far: 6921
# Search term: Cheese Chicken Thighs
# Total recipes found so far: 6927
# Search term: Cheese Chicken Thighs
# Total recipes found so far: 6927
# Search term: Cheese Chicken Thighs
# Total recipes found so far: 6927
# Search term: Cheese Chicken Breasts
# Total recipes found so far: 6937
# Search term: Cheese Chicken Breasts
# Total recipes found so far: 6937
# Search term: Cheese Chicken Breasts
# Total recipes found so far: 6937
# Search term: Cheese Turkey Legs
# Total recipes found so far: 6937
# Search term: Cheese Turkey Legs
# Total recipes found so far: 6937
# Search term: Cheese Turkey Breast
# Total recipes found so far: 6942
# Search term: Cheese Turkey Breast
# Total recipes found so far: 6942
# Search term: Cheese Turkey Breast
# Total recipes found so far: 6942
# Search term: Cheese Duck Breast
# Total recipes found so far: 6942
# Search term: Cheese Duck Breast
# Total recipes found so far: 6942
# Search term: Cheese Lamb Chops
# Total recipes found so far: 6946
# Search term: Cheese Lamb Chops
# Total recipes found so far: 6946
# Search term: Cheese Lamb Chops
# Total recipes found so far: 6946
# Search term: Cheese Lamb Shanks
# Total recipes found so far: 6946
# Search term: Cheese Lamb Shanks
# Total recipes found so far: 6946
# Search term: Cheese Tofu Stir Fry
# Total recipes found so far: 6946
# ...
# Search term: Lentils Ribs
# Total recipes found so far: 9619
# Search term: Lentils Salmon
# Total recipes found so far: 9619
# Search term: Lentils Salmon
# Total recipes found so far: 9619
# Search term: Lentils Scallops
# Total recipes found so far: 9619
# Search term: Lentils Scallops
# Total recipes found so far: 9619
# Search term: Lentils Oysters
# Total recipes found so far: 9619
# Search term: Lentils Oysters
# Total recipes found so far: 9619
# Search term: Lentils Chicken Thighs
# Total recipes found so far: 9619
# Search term: Lentils Chicken Thighs
# Total recipes found so far: 9619
# Search term: Lentils Chicken Breasts
# Total recipes found so far: 9621
# Search term: Lentils Chicken Breasts
# Total recipes found so far: 9621
# Search term: Lentils Chicken Breasts
# Total recipes found so far: 9621
# Search term: Lentils Lamb Chops
# Total recipes found so far: 9621
# Search term: Lentils Lamb Chops
# Total recipes found so far: 9621
# Search term: Lentils Lamb Shanks
# Total recipes found so far: 9621
# Search term: Lentils Lamb Shanks
# Total recipes found so far: 9621
# Search term: Lentils Tofu Stir Fry
# Total recipes found so far: 9621
# Search term: Lentils Tofu Stir Fry
# Total recipes found so far: 9621
# Search term: Lentils Cheese Sauce
# Total recipes found so far: 9622
# Search term: Lentils Cheese Sauce
# Total recipes found so far: 9622
# Search term: Lentils Cheese Sauce
# Total recipes found so far: 9622
# Search term: Lentils Pasta Salad
# Total recipes found so far: 9622
# Search term: Lentils Pasta Salad
# Total recipes found so far: 9622
# Search term: Lentils Spaghetti
# Total recipes found so far: 9622
# Search term: Lentils Spaghetti
# Total recipes found so far: 9622
# Search term: Lentils Fried Rice
# Total recipes found so far: 9622
# Search term: Lentils Fried Rice
# Total recipes found so far: 9622
# Search term: Lentils Risotto
# Total recipes found so far: 9622
# Search term: Lentils Risotto
# Total recipes found so far: 9622
# Search term: Lentils Mashed Potatoes
# Total recipes found so far: 9622
# Search term: Lentils Mashed Potatoes
# Total recipes found so far: 9622
# Search term: Lentils Baked Potatoes
# Total recipes found so far: 9623
# Search term: Lentils Baked Potatoes
# Total recipes found so far: 9623
# Search term: Lentils Baked Potatoes
# Total recipes found so far: 9623
# Search term: Lentils Vegetable Soup
# Total recipes found so far: 9625
# Search term: Lentils Vegetable Soup
# Total recipes found so far: 9625
# Search term: Lentils Vegetable Soup
# Total recipes found so far: 9625
# Search term: Lentils Chicken Soup
# Total recipes found so far: 9625
# Search term: Lentils Chicken Soup
# Total recipes found so far: 9625
# Search term: Lentils Beef Stew
# Total recipes found so far: 9625
# Search term: Lentils Beef Stew
# Total recipes found so far: 9625
# Search term: Lentils Pork Roast
# Total recipes found so far: 9625
# Search term: Lentils Pork Roast
# Total recipes found so far: 9625
# Search term: Lentils Tofu Curry
# Total recipes found so far: 9625
# Search term: Lentils Tofu Curry
# Total recipes found so far: 9625
# Search term: Lentils Veggie Burger
# Total recipes found so far: 9625
# Search term: Lentils Veggie Burger
# Total recipes found so far: 9625
# Search term: Lentils Pancakes
# Total recipes found so far: 9626
# Search term: Lentils Pancakes
# Total recipes found so far: 9626
# Search term: Lentils Pancakes
# Total recipes found so far: 9626
# Search term: Soup Salad
# Total recipes found so far: 9630
# Search term: Soup Salad
# Total recipes found so far: 9630
# Search term: Soup Salad
# Total recipes found so far: 9630
# Search term: Soup Bread
# Total recipes found so far: 9640
# Search term: Soup Bread
# Total recipes found so far: 9640
# Search term: Soup Bread
# Total recipes found so far: 9640
# Search term: Soup Noodles
# Total recipes found so far: 9644
# Search term: Soup Noodles
# Total recipes found so far: 9644
# Search term: Soup Noodles
# Total recipes found so far: 9644
# Search term: Soup Tomatoes
# Total recipes found so far: 9657
# Search term: Soup Tomatoes
# Total recipes found so far: 9657
# Search term: Soup Tomatoes
# Total recipes found so far: 9657
# Search term: Soup Garlic
# Total recipes found so far: 9666
# Search term: Soup Garlic
# Total recipes found so far: 9666
# Search term: Soup Garlic
# Total recipes found so far: 9666
# Search term: Soup Onions
# Total recipes found so far: 9676
# Search term: Soup Onions
# Total recipes found so far: 9676
# Search term: Soup Onions
# Total recipes found so far: 9676
# Search term: Soup Carrots
# Total recipes found so far: 9689
# Search term: Soup Carrots
# Total recipes found so far: 9689
# Search term: Soup Carrots
# Total recipes found so far: 9689
# Search term: Soup Spinach
# Total recipes found so far: 9698
# Search term: Soup Spinach
# Total recipes found so far: 9698
# Search term: Soup Spinach
# Total recipes found so far: 9698
# Search term: Soup Broccoli
# Total recipes found so far: 9708
# Search term: Soup Broccoli
# Total recipes found so far: 9708
# Search term: Soup Broccoli
# Total recipes found so far: 9708
# Search term: Soup Cauliflower
# Total recipes found so far: 9717
# Search term: Soup Cauliflower
# Total recipes found so far: 9717
# Search term: Soup Cauliflower
# Total recipes found so far: 9717
# Search term: Soup Cabbage
# Total recipes found so far: 9722
# Search term: Soup Cabbage
# Total recipes found so far: 9722
# Search term: Soup Cabbage
# Total recipes found so far: 9722
# Search term: Soup Peppers
# Total recipes found so far: 9735
# Search term: Soup Peppers
# Total recipes found so far: 9735
# Search term: Soup Peppers
# Total recipes found so far: 9735
# Search term: Soup Mushrooms
# Total recipes found so far: 9751
# Search term: Soup Mushrooms
# Total recipes found so far: 9751
# Search term: Soup Mushrooms
# Total recipes found so far: 9751
# Search term: Soup Zucchini
# Total recipes found so far: 9763
# Search term: Soup Zucchini
# Total recipes found so far: 9763
# Search term: Soup Zucchini
# Total recipes found so far: 9763
# Search term: Soup Squash
# Total recipes found so far: 9772
# Search term: Soup Squash
# Total recipes found so far: 9772
# Search term: Soup Squash
# Total recipes found so far: 9772
# Search term: Soup Avocado
# Total recipes found so far: 9778
# Search term: Soup Avocado
# Total recipes found so far: 9778
# Search term: Soup Avocado
# Total recipes found so far: 9778
# Search term: Soup Apples
# Total recipes found so far: 9790
# Search term: Soup Apples
# Total recipes found so far: 9790
# Search term: Soup Apples
# Total recipes found so far: 9790
# Search term: Soup Oranges
# Total recipes found so far: 9802
# Search term: Soup Oranges
# Total recipes found so far: 9802
# Search term: Soup Oranges
# Total recipes found so far: 9802
# Search term: Soup Bananas
# Total recipes found so far: 9806
# Search term: Soup Bananas
# Total recipes found so far: 9806
# Search term: Soup Bananas
# Total recipes found so far: 9806
# Search term: Soup Berries
# Total recipes found so far: 9806
# Search term: Soup Berries
# Total recipes found so far: 9806
# Search term: Soup Grapes
# Total recipes found so far: 9808
# Search term: Soup Grapes
# Total recipes found so far: 9808
# Search term: Soup Grapes
# Total recipes found so far: 9808
# Search term: Soup Pineapple
# Total recipes found so far: 9812
# Search term: Soup Pineapple
# Total recipes found so far: 9812
# Search term: Soup Pineapple
# Total recipes found so far: 9812
# Search term: Soup Mango
# Total recipes found so far: 9813
# Search term: Soup Mango
# Total recipes found so far: 9813
# Search term: Soup Mango
# Total recipes found so far: 9813
# Search term: Soup Melons
# Total recipes found so far: 9816
# Search term: Soup Melons
# Total recipes found so far: 9816
# Search term: Soup Melons
# Total recipes found so far: 9816
# Search term: Soup Yams
# Total recipes found so far: 9817
# Search term: Soup Yams
# Total recipes found so far: 9817
# Search term: Soup Yams
# Total recipes found so far: 9817
# Search term: Soup Sweet Potatoes
# Total recipes found so far: 9825
# Search term: Soup Sweet Potatoes
# Total recipes found so far: 9825
# Search term: Soup Sweet Potatoes
# Total recipes found so far: 9825
# Search term: Soup Corn
# Total recipes found so far: 9837
# Search term: Soup Corn
# Total recipes found so far: 9837
# Search term: Soup Corn
# Total recipes found so far: 9837
# Search term: Soup Peas
# Total recipes found so far: 9852
# Search term: Soup Peas
# Total recipes found so far: 9852
# Search term: Soup Peas
# Total recipes found so far: 9852
# Search term: Soup Cucumber
# Total recipes found so far: 9861
# Search term: Soup Cucumber
# Total recipes found so far: 9861
# Search term: Soup Cucumber
# Total recipes found so far: 9861
# Search term: Soup Radishes
# Total recipes found so far: 9862
# Search term: Soup Radishes
# Total recipes found so far: 9862
# Search term: Soup Radishes
# Total recipes found so far: 9862
# Search term: Soup Herbs
# Total recipes found so far: 9865
# Search term: Soup Herbs
# Total recipes found so far: 9865
# Search term: Soup Herbs
# Total recipes found so far: 9865
# Search term: Soup Spices
# Total recipes found so far: 9869
# Search term: Soup Spices
# Total recipes found so far: 9869
# Search term: Soup Spices
# Total recipes found so far: 9869
# Search term: Soup Beefsteak
# Total recipes found so far: 9869
# Search term: Soup Beefsteak
# Total recipes found so far: 9869
# Search term: Soup Short Ribs
# Total recipes found so far: 9870
# Search term: Soup Short Ribs
# Total recipes found so far: 9870
# Search term: Soup Short Ribs
# Total recipes found so far: 9870
# Search term: Soup Filet Mignon
# Total recipes found so far: 9870
# Search term: Soup Filet Mignon
# Total recipes found so far: 9870
# Search term: Soup Brisket
# Total recipes found so far: 9872
# Search term: Soup Brisket
# Total recipes found so far: 9872
# Search term: Soup Brisket
# Total recipes found so far: 9872
# Search term: Soup Pork Chops
# Total recipes found so far: 9880
# Search term: Soup Pork Chops
# Total recipes found so far: 9880
# Search term: Soup Pork Chops
# Total recipes found so far: 9880
# Search term: Soup Sausages
# Total recipes found so far: 9881
# Search term: Soup Sausages
# Total recipes found so far: 9881
# Search term: Soup Sausages
# Total recipes found so far: 9881
# Search term: Soup Ribs
# Total recipes found so far: 9884
# Search term: Soup Ribs
# Total recipes found so far: 9884
# Search term: Soup Ribs
# Total recipes found so far: 9884
# Search term: Soup Salmon
# Total recipes found so far: 9890
# Search term: Soup Salmon
# Total recipes found so far: 9890
# Search term: Soup Salmon
# Total recipes found so far: 9890
# Search term: Soup Tuna
# Total recipes found so far: 9897
# Search term: Soup Tuna
# Total recipes found so far: 9897
# Search term: Soup Tuna
# Total recipes found so far: 9897
# Search term: Soup Cod
# Total recipes found so far: 9897
# Search term: Soup Cod
# Total recipes found so far: 9897
# Search term: Soup Scallops
# Total recipes found so far: 9901
# Search term: Soup Scallops
# Total recipes found so far: 9901
# Search term: Soup Scallops
# Total recipes found so far: 9901
# Search term: Soup Crab
# Total recipes found so far: 9904
# Search term: Soup Crab
# Total recipes found so far: 9904
# Search term: Soup Crab
# Total recipes found so far: 9904
# Search term: Soup Clams
# Total recipes found so far: 9904
# Search term: Soup Clams
# Total recipes found so far: 9904
# Search term: Soup Mussels
# Total recipes found so far: 9904
# Search term: Soup Mussels
# Total recipes found so far: 9904
# Search term: Soup Oysters
# Total recipes found so far: 9909
# Search term: Soup Oysters
# Total recipes found so far: 9909
# Search term: Soup Oysters
# Total recipes found so far: 9909
# Search term: Soup Chicken Wings
# Total recipes found so far: 9912
# Search term: Soup Chicken Wings
# Total recipes found so far: 9912
# Search term: Soup Chicken Wings
# Total recipes found so far: 9912
# Search term: Soup Chicken Thighs
# Total recipes found so far: 9919
# Search term: Soup Chicken Thighs
# Total recipes found so far: 9919
# Search term: Soup Chicken Thighs
# Total recipes found so far: 9919
# Search term: Soup Chicken Breasts
# Total recipes found so far: 9926
# Search term: Soup Chicken Breasts
# Total recipes found so far: 9926
# Search term: Soup Chicken Breasts
# Total recipes found so far: 9926
# Search term: Soup Turkey Legs
# Total recipes found so far: 9926
# Search term: Soup Turkey Legs
# Total recipes found so far: 9926
# Search term: Soup Turkey Breast
# Total recipes found so far: 9926
# Search term: Soup Turkey Breast
# Total recipes found so far: 9926
# Search term: Soup Lamb Chops
# Total recipes found so far: 9926
# Search term: Soup Lamb Chops
# Total recipes found so far: 9926
# Search term: Soup Lamb Shanks
# Total recipes found so far: 9926
# Search term: Soup Lamb Shanks
# Total recipes found so far: 9926
# Search term: Soup Tofu Stir Fry
# Total recipes found so far: 9927
# Search term: Soup Tofu Stir Fry
# Total recipes found so far: 9927
# Search term: Soup Tofu Stir Fry
# Total recipes found so far: 9927
# Search term: Soup Cheese Sauce
# Total recipes found so far: 9933
# Search term: Soup Cheese Sauce
# Total recipes found so far: 9933
# Search term: Soup Cheese Sauce
# Total recipes found so far: 9933
# Search term: Soup Pasta Salad
# Total recipes found so far: 9934
# Search term: Soup Pasta Salad
# Total recipes found so far: 9934
# Search term: Soup Pasta Salad
# Total recipes found so far: 9934
# Search term: Soup Spaghetti
# Total recipes found so far: 9938
# Search term: Soup Spaghetti
# Total recipes found so far: 9938
# Search term: Soup Spaghetti
# Total recipes found so far: 9938
# Search term: Soup Lasagna
# Total recipes found so far: 9940
# Search term: Soup Lasagna
# Total recipes found so far: 9940
# Search term: Soup Lasagna
# Total recipes found so far: 9940
# Search term: Soup Fried Rice
# Total recipes found so far: 9942
# Search term: Soup Fried Rice
# Total recipes found so far: 9942
# Search term: Soup Fried Rice
# Total recipes found so far: 9942
# Search term: Soup Risotto
# Total recipes found so far: 9942
# Search term: Soup Risotto
# Total recipes found so far: 9942
# Search term: Soup Potato Salad
# Total recipes found so far: 9942
# Search term: Soup Potato Salad
# Total recipes found so far: 9942
# Search term: Soup Mashed Potatoes
# Total recipes found so far: 9948
# Search term: Soup Mashed Potatoes
# Total recipes found so far: 9948
# Search term: Soup Mashed Potatoes
# Total recipes found so far: 9948
# Search term: Soup Baked Potatoes
# Total recipes found so far: 9957
# Search term: Soup Baked Potatoes
# Total recipes found so far: 9957
# Search term: Soup Baked Potatoes
# Total recipes found so far: 9957
# Search term: Soup Vegetable Soup
# Total recipes found so far: 9957
# Search term: Soup Vegetable Soup
# Total recipes found so far: 9957
# Search term: Soup Chicken Soup
# Total recipes found so far: 9957
# Search term: Soup Chicken Soup
# Total recipes found so far: 9957
# Search term: Soup Beef Stew
# Total recipes found so far: 9958
# Search term: Soup Beef Stew
# Total recipes found so far: 9958
# Search term: Soup Beef Stew
# Total recipes found so far: 9958
# Search term: Soup Pork Roast
# Total recipes found so far: 9961
# Search term: Soup Pork Roast
# Total recipes found so far: 9961
# Search term: Soup Pork Roast
# Total recipes found so far: 9961
# Search term: Soup Tofu Curry
# Total recipes found so far: 9962
# Search term: Soup Tofu Curry
# Total recipes found so far: 9962
# Search term: Soup Tofu Curry
# Total recipes found so far: 9962
# Search term: Soup Veggie Burger
# Total recipes found so far: 9963
# Search term: Soup Veggie Burger
# Total recipes found so far: 9963
# Search term: Soup Veggie Burger
# Total recipes found so far: 9963
# Search term: Soup Fruit Salad
# Total recipes found so far: 9964
# Search term: Soup Fruit Salad
# Total recipes found so far: 9964
# Search term: Soup Fruit Salad
# Total recipes found so far: 9964
# Search term: Soup Pancakes
# Total recipes found so far: 9966
# Search term: Soup Pancakes
# Total recipes found so far: 9966
# Search term: Soup Pancakes
# Total recipes found so far: 9966
# Search term: Salad Bread
# Total recipes found so far: 9977
# Search term: Salad Bread
# Total recipes found so far: 9977
# Search term: Salad Bread
# Total recipes found so far: 9977
# Search term: Salad Noodles
# Total recipes found so far: 9989
# Search term: Salad Noodles
# Total recipes found so far: 9989
# Search term: Salad Noodles
# Total recipes found so far: 9989
# Search term: Salad Tomatoes
# Total recipes found so far: 10002
#
# Final Total Recipes Found: 10002
# Data successfully written to recipes.csv

# %% [markdown]
# **Question 1: Part (A)**
#
# In this phase, we gather comprehensive data by scraping the recipes from the URLs previously extracted and stored in a CSV file. For each URL, we send an HTTP request to retrieve the HTML content of the recipe page. The HTML is then parsed to extract detailed information including the recipe title, ingredients, directions, nutritional facts, author details, and update date.
#
# We employ functions to clean and validate URLs, ensuring accurate and reliable access to each recipe page. The extracted data is structured and stored in a list, which is subsequently saved as a JSON file. This process consolidates all relevant recipe information from the URLs into a single, comprehensive dataset, facilitating further analysis and utilization.

# %%
import csv
import requests
from bs4 import BeautifulSoup
import json

# Read the URLs from the CSV file
with open('recipes.csv', newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    urls = [row['link'] for row in reader]

# Initialize a list to store all recipes
all_recipes = []

# Function to clean and validate URLs
def clean_url(url):
    if url.startswith('https://www.allrecipes.comhttps://'):
        url = url.replace('https://www.allrecipes.comhttps://', 'https://')
    elif not url.startswith('http'):
        url = 'https://' + url.lstrip('/')
    return url

def scrape_recipe(url, recipe_id):
    # Clean the URL
    url = clean_url(url)

    try:
        # Send a request to fetch the HTML content
        response = requests.get(url)
        response.raise_for_status()  # Check for HTTP errors
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the title using the given class
        title_tag = soup.find('h1', class_='article-heading type--lion')
        title = title_tag.get_text(strip=True) if title_tag else 'Title not found'

        # Extract recipe details
        details = {}
        for item in soup.select('.mm-recipes-details__item'):
            label = item.select_one('.mm-recipes-details__label').get_text(strip=True)
            value = item.select_one('.mm-recipes-details__value').get_text(strip=True)
            details[label] = value

        # Extract ingredients
        ingredients = []
        ingredients_section = soup.find('h2', class_='mm-recipes-structured-ingredients__heading')
        if ingredients_section:
            ingredient_list = ingredients_section.find_next('ul')
            for ingredient in ingredient_list.find_all('li'):
                ingredient_text = ' '.join(ingredient.stripped_strings)
                ingredients.append(ingredient_text)

        # Extract directions
        directions = []
        directions_section = soup.find('h2', class_='mm-recipes-steps__heading')
        if directions_section:
            steps_list = directions_section.find_next('ol')
            if steps_list:
                for step in steps_list.find_all('li'):
                    step_text = ' '.join(step.stripped_strings)
                    directions.append(step_text)

        # Extract nutritional facts
        nutrition_facts = {}
        nutrition_section = soup.find('h2', class_='mm-recipes-nutrition-facts-summary__heading')
        if nutrition_section:
            nutrition_table = nutrition_section.find_next('table')
            if nutrition_table:
                for row in nutrition_table.find_all('tr'):
                    cols = row.find_all('td')
                    if len(cols) == 2:
                        nutrient = cols[0].get_text(strip=True)
                        amount = cols[1].get_text(strip=True)
                        nutrition_facts[nutrient] = amount

        # Extract author information
        author_info = {}
        author_section = soup.find('div', class_='allrecipes-bylines')
        if author_section:
            author_name_tag = author_section.find('a', class_='mntl-attribution__item-name')
            author_name = author_name_tag.get_text(strip=True) if author_name_tag else 'Author not found'
            author_link = author_name_tag['href'] if author_name_tag else None

            author_bio_tag = author_section.find('div', class_='mntl-author-tooltip__bio')
            author_bio = author_bio_tag.get_text(strip=True) if author_bio_tag else 'Bio not available'

            author_info = {
                'name': author_name,
                'link': author_link,
                'bio': author_bio
            }

        # Extract update date
        update_date_tag = author_section.find('div', class_='mntl-attribution__item-date')
        update_date = update_date_tag.get_text(strip=True) if update_date_tag else 'Update date not available'

        # Create a dictionary with the URL, title, details, ingredients, directions, nutrition facts, author info, and update date
        data = {
            'id': recipe_id,
            'url': url,
            'title': title,
            'details': details,
            'ingredients': ingredients,
            'directions': directions,
            'nutrition_facts': nutrition_facts,
            'author_info': author_info,
            'update_date': update_date
        }

        # Add the recipe data to the list of all recipes
        all_recipes.append(data)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
k = 0
# Loop through each URL and scrape the recipe
for i, url in enumerate(urls, start=1):
    print(f'Fetching the data from {k}th file ....')
    scrape_recipe(url, i)
    k += 1

# Save all recipes to a single JSON file
with open('Question1_A_RawData.json', 'w') as file:
    json.dump(all_recipes, file, indent=4)

print(f'Data saved to Question1_A_RawData.json with {len(all_recipes)} recipes.')
# Out:
# Streaming output truncated to the last 5000 lines.
# Fetching the data from 5003th file ....
# Fetching the data from 5004th file ....
# Fetching the data from 5005th file ....
# Fetching the data from 5006th file ....
# Fetching the data from 5007th file ....
# Fetching the data from 5008th file ....
# Fetching the data from 5009th file ....
# Fetching the data from 5010th file ....
# Fetching the data from 5011th file ....
# Fetching the data from 5012th file ....
# Fetching the data from 5013th file ....
# Fetching the data from 5014th file ....
# Fetching the data from 5015th file ....
# Fetching the data from 5016th file ....
# Fetching the data from 5017th file ....
# Fetching the data from 5018th file ....
# Fetching the data from 5019th file ....
# Fetching the data from 5020th file ....
# Fetching the data from 5021th file ....
# Fetching the data from 5022th file ....
# Fetching the data from 5023th file ....
# Fetching the data from 5024th file ....
# Fetching the data from 5025th file ....
# Fetching the data from 5026th file ....
# Fetching the data from 5027th file ....
# Fetching the data from 5028th file ....
# Fetching the data from 5029th file ....
# Fetching the data from 5030th file ....
# Fetching the data from 5031th file ....
# Fetching the data from 5032th file ....
# Fetching the data from 5033th file ....
# Fetching the data from 5034th file ....
# Fetching the data from 5035th file ....
# Fetching the data from 5036th file ....
# Fetching the data from 5037th file ....
# Fetching the data from 5038th file ....
# Fetching the data from 5039th file ....
# Fetching the data from 5040th file ....
# Fetching the data from 5041th file ....
# Fetching the data from 5042th file ....
# Fetching the data from 5043th file ....
# Fetching the data from 5044th file ....
# Fetching the data from 5045th file ....
# Fetching the data from 5046th file ....
# Fetching the data from 5047th file ....
# Fetching the data from 5048th file ....
# Fetching the data from 5049th file ....
# Fetching the data from 5050th file ....
# Fetching the data from 9987th file ....
# Fetching the data from 9988th file ....
# Fetching the data from 9989th file ....
# Fetching the data from 9990th file ....
# Fetching the data from 9991th file ....
# Fetching the data from 9992th file ....
# Fetching the data from 9993th file ....
# Fetching the data from 9994th file ....
# Fetching the data from 9995th file ....
# Fetching the data from 9996th file ....
# Fetching the data from 9997th file ....
# Fetching the data from 9998th file ....
# Fetching the data from 9999th file ....
# Fetching the data from 10000th file ....
# Fetching the data from 10001th file ....
# Data saved to recipes_10k.json with 10002 recipes.

# %% [markdown]
# **We have converted the JSON data into a CSV file for easier analysis and manipulation.**

# %%
import pandas as pd
import json

# Load JSON data
with open('Question1_A_RawData.json') as json_file:
    data = json.load(json_file)

# Convert JSON to DataFrame
df = pd.json_normalize(data)

# Save DataFrame to CSV
df.to_csv('Question1_A_RawData.csv', index=False)

# %% [markdown]
# ```
# # install dependency
# ```

# %%
pip install ijson
# Out:
# Collecting ijson
#   Downloading ijson-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Downloading ijson-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: ijson
# Successfully installed ijson-3.3.0

# %% [markdown]
# **Question 1: Part (B)**
#
# In this script, we use Named Entity Recognition (NER) to extract ingredient names from a JSON file containing recipes. Here’s a detailed breakdown:
#
# 1. **Load SpaCy Model**: We start by loading SpaCy’s NER model (`en_core_web_sm`) to process and extract named entities from text.
#
# 2. **Read JSON File**: We use `ijson` to handle large JSON files efficiently and read the recipes from `Question1_A_RawData`. We handle encoding errors gracefully.
#
# 3. **Process Ingredients**: For each recipe, we extract the list of ingredients and apply the SpaCy NER model to identify named entities. We print these entities and their labels for debugging purposes.
#
# 4. **Filter and Extract Ingredient Names**:
#    - **Tokenization**: We tokenize the ingredient phrases and filter out common non-ingredient words and unwanted parts of speech (e.g., stop words, digits).
#    - **Ingredient Extraction**: We assume that the last token in the filtered list often represents the ingredient name. We collect these names along with their corresponding recipe IDs.
#
# 5. **Data Collection**: We store unique ingredients with their recipe IDs in a set to avoid duplicates.
#
# 6. **Convert to DataFrame**: We convert the collected ingredient data into a Pandas DataFrame, remove any duplicate entries, and sort by Recipe ID.
#
# 7. **Output and Save**: We print the sorted ingredient data and save the results to a CSV file (`Question1_B.csv`), providing an organized format for further analysis.
#
# This approach ensures that we efficiently extract and organize ingredient names from a large dataset, using NER to enhance the accuracy of the ingredient identification process.

# %%
import spacy
import ijson
import pandas as pd
import re
from collections import defaultdict

# Load SpaCy's NER model
nlp = spacy.load("en_core_web_sm")

# File path to the large JSON file
file_path = 'Question1_A_RawData.json'

# Set to store unique ingredients with their recipe ID
unique_ingredients = set()

# Define a function to clean ingredient names
def clean_ingredient_name(name):
    # Remove special characters and digits
    cleaned_name = re.sub(r'[^a-zA-Z\s]', '', name)  # Keep only letters and spaces
    return cleaned_name.strip()

# Open the JSON file, handling encoding errors
with open(file_path, 'r', encoding='utf-8', errors='replace') as f:
    # Parse recipes array using ijson
    recipes = ijson.items(f, 'item')

    count = 0  # Counter to limit to 10 recipes

    # Loop through each recipe in the JSON file
    for recipe in recipes:
        try:
            recipe_id = recipe.get("id", None)  # Use the pre-assigned recipe ID
            ingredients = recipe.get("ingredients", [])

            # Process each ingredient phrase
            for ingredient_phrase in ingredients:
                # Apply NER using SpaCy to extract named entities
                doc = nlp(ingredient_phrase)

                # Print entities and their labels for debugging
                print(f"Processing ingredients for recipe {recipe_id}")
                for ent in doc.ents:
                    print(f"Entity: {ent.text}, Label: {ent.label_}")  # Print all recognized entities

                # Processing ingredients to extract main ingredient names using POS tagging
                ingredient_parts = []
                for token in doc:
                    # Filter out stop words, digits, and unwanted POS tags
                    if token.pos_ in ['NOUN', 'PROPN'] and not token.text.isdigit():
                        ingredient_parts.append(token.text.lower())

                # Filter out common non-ingredient keywords and special characters
                non_keywords = {'cups', 'cup', 'tablespoons', 'tablespoon', 'teaspoons', 'teaspoon', 'optional',
                                'packed', 'all-purpose', 'inch', 'pie', 'shell', 'divided',
                                'smoke', 'chopped', 'roast', 'sliced', 'crushed', 'powder', 'pieces', 'taste', 'packet', 'chuck', ')', ',', '(', 'thinly'}
                filtered_ingredients = [word for word in ingredient_parts if word not in non_keywords]

                # Clean ingredient names and remove any that are empty
                cleaned_ingredients = [clean_ingredient_name(word) for word in filtered_ingredients if clean_ingredient_name(word)]

                if cleaned_ingredients:
                    # Add the last cleaned word which often is the ingredient name along with recipe ID
                    unique_ingredients.add((recipe_id, cleaned_ingredients[-1]))

            count += 1
            if count == 10002:
                break

        except Exception as e:
            print(f"Error processing recipe {recipe_id}: {e}")
            continue

# Convert the collected data to a DataFrame
df = pd.DataFrame(list(unique_ingredients), columns=["Recipe ID", "Ingredient"])

# Remove duplicates, if needed
df = df.drop_duplicates(subset=["Recipe ID", "Ingredient"])

# Sort the DataFrame by Recipe ID
df = df.sort_values(by="Recipe ID")

# Print the sorted result
print("\nRecipe ID | Ingredient Name")
for index, row in df.iterrows():
    print(f"{row['Recipe ID']} | {row['Ingredient']}")

# Save the results to a CSV file
df.to_csv('Question1_B.csv', index=False)

print("Ingredient extraction complete. Data saved to 'Question1_B.csv'.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 9490 | tortillas
# 9490 | onion
# 9490 | cheese
# 9490 | beans
# 9491 | cheese
# 9491 | beans
# 9491 | onion
# 9491 | squash
# 9491 | tortillas
# 9491 | jar
# 9491 | spray
# 9492 | eggs
# 9492 | soy
# 9492 | ham
# 9492 | salt
# 9492 | onions
# 9492 | carrots
# 9492 | sprouts
# 9492 | rice
# 9492 | oil
# 9492 | pepper
# 9493 | oil
# 9493 | plantains
# 9493 | salt
# 9494 | sauce
# 9494 | onion
# 9494 | potatoes
# 9494 | pepper
# 9494 | beans
# 9494 | juice
# 9494 | mustard
# 9494 | garlic
# 9494 | vinegar
# 9494 | oil
# 9494 | basil
# 9495 | pepper
# 9495 | mustard
# 9495 | honey
# 9495 | shallot
# 9495 | oil
# 9495 | garlic
# 9495 | vinegar
# 9496 | crumbs
# 9496 | beef
# 9496 | sauce
# 9496 | mix
# 9496 | water
# 9497 | yeast
# 9497 | avocado
# 9497 | onion
# 9497 | beans
# 9497 | juice
# 9497 | salt
# 9497 | potatoes
# 9497 | mustard
# 9497 | slices
# 9498 | soy
# 9498 | pepper
# 9498 | water
# 9498 | tortillas
# 9498 | potatoes
# 9498 | beans
# 9498 | mustard
# 9498 | cloves
# 9498 | cumin
# 9498 | oil
# 9498 | cheese
# 9498 | onion
# 9498 | chili
# 9499 | beans
# 9499 | water
# 9499 | cloves
# 9499 | epazote
# 9500 | lengthwise
# 9500 | pepper
# 9500 | water
# 9500 | salt
# 9500 | cumin
# 9500 | size
# 9500 | parsley
# 9500 | beans
# 9500 | butter
# 9500 | oil
# 9500 | leaves
# 9500 | bacon
# 9500 | celery
# 9500 | onion
# 9500 | stock
# 9501 | garlic
# 9501 | beans
# 9501 | onion
# 9501 | cumin
# 9501 | grease
# 9502 | water
# 9502 | beans
# 9502 | bacon
# 9502 | cumin
# 9502 | salt
# 9502 | paprika
# 9502 | onions
# 9502 | peppers
# 9502 | broth
# 9503 | tortillas
# 9503 | spinach
# 9503 | beans
# 9503 | salt
# 9503 | onion
# 9503 | ground
# 9503 | cob
# 9503 | pepper
# 9503 | blend
# 9503 | oil
# 9503 | cumin
# 9503 | ounce
# 9503 | cloves
# 9503 | parsley
# 9504 | beef
# 9504 | salt
# 9504 | tomatoes
# 9504 | gravy
# 9504 | onion
# 9504 | leaves
# 9504 | niblets
# 9504 | beans
# 9504 | potatoes
# 9505 | cloves
# 9505 | leaves
# 9505 | foil
# 9505 | onion
# 9505 | salt
# 9505 | yogurt
# 9505 | oil
# 9505 | shallots
# 9505 | juice
# 9505 | beans
# 9505 | sauce
# 9505 | potatoes
# 9506 | pepper
# 9506 | carrots
# 9506 | cloves
# 9506 | onion
# 9506 | chili
# 9506 | corn
# 9506 | cumin
# 9506 | oil
# 9506 | broth
# 9506 | beans
# 9506 | tomatoes
# 9507 | onion
# 9507 | cabbage
# 9507 | cocktail
# 9507 | tomatoes
# 9507 | beef
# 9507 | juice
# 9507 | corn
# 9507 | chili
# 9507 | celery
# 9507 | pepper
# 9507 | beans
# 9508 | water
# 9508 | ounce
# 9508 | carrots
# 9508 | tomatoes
# 9508 | pepper
# 9508 | garlic
# 9508 | beans
# 9508 | creole
# 9508 | pasta
# 9508 | mushrooms
# 9508 | broth
# 9509 | water
# 9509 | beans
# 9509 | mix
# 9509 | corn
# 9509 | pepper
# 9509 | beef
# 9509 | tomatoes
# 9509 | onion
# 9509 | olives
# 9509 | rotel
# 9509 | ranch
# 9510 | corn
# 9510 | size
# 9510 | chili
# 9510 | cumin
# 9510 | broth
# 9510 | oil
# 9510 | cilantro
# 9510 | beans
# 9510 | strips
# 9511 | onion
# 9511 | taco
# 9511 | beans
# 9511 | sauce
# 9511 | cubes
# 9511 | corn
# 9511 | broth
# 9511 | cheese
# 9511 | oil
# 9512 | tomatoes
# 9512 | oil
# 9512 | beans
# 9512 | ounce
# 9512 | chicken
# 9512 | cumin
# 9512 | water
# 9512 | cilantro
# 9512 | onion
# 9512 | broth
# 9526 | pepper
# 9526 | garlic
# 9526 | potatoes
# 9526 | beef
# 9526 | sugar
# 9527 | cloves
# 9527 | beans
# 9527 | vinegar
# 9527 | shoulder
# 9527 | lettuce
# 9527 | oil
# 9527 | seasoning
# 9527 | tomatoes
# 9527 | pepper
# 9528 | peas
# 9528 | stock
# 9528 | pork
# 9528 | celery
# 9528 | cumin
# 9528 | butternut
# 9528 | beans
# 9528 | oil
# 9528 | cloves
# 9528 | corn
# 9528 | salt
# 9528 | tomatoes
# 9528 | pepper
# 9528 | sauce
# 9528 | paprika
# 9528 | onions
# 9529 | beans
# 9529 | cilantro
# 9529 | juice
# 9529 | onion
# 9529 | pepper
# 9529 | kernels
# 9530 | banana
# 9530 | blueberries
# 9530 | milk
# 9530 | extract
# 9530 | oats
# 9530 | syrup
# 9531 | flour
# 9531 | water
# 9531 | oats
# 9531 | cinnamon
# 9531 | cornmeal
# 9532 | lettuce
# 9532 | onion
# 9532 | avocado
# 9532 | drumsticks
# 9532 | garlic
# 9532 | maseca
# 9532 | tomato
# 9532 | granules
# 9532 | water
# 9532 | goya
# 9532 | cream
# 9532 | frying
# 9532 | cheese
# 9532 | salt
# 9533 | sauce
# 9533 | carrots
# 9533 | stock
# 9533 | onions
# 9533 | eggs
# 9533 | flour
# 9533 | oil
# 9533 | strips
# 9533 | chicken
# 9533 | cabbage
# 9533 | beans
# 9534 | pepper
# 9534 | corn
# 9534 | beans
# 9534 | basil
# 9534 | stock
# 9534 | oil
# 9534 | onion
# 9534 | butternut
# 9535 | sugar
# 9535 | extract
# 9535 | seasonings
# 9535 | cornstarch
# 9535 | nutmeg
# 9535 | peaches
# 9536 | oil
# 9536 | leaves
# 9536 | paste
# 9536 | vinegar
# 9536 | garlic
# 9536 | onion
# 9536 | carrot
# 9536 | pepper
# 9536 | pinch
# 9536 | water
# 9536 | lentils
# 9537 | onion
# 9537 | granules
# 9537 | meat
# 9537 | lentils
# 9537 | carrots
# 9537 | marjoram
# 9537 | pepper
# 9537 | leaf
# 9537 | water
# 9537 | celery
# 9538 | nutmeg
# 9538 | curry
# 9538 | squash
# 9538 | cilantro
# 9538 | water
# 9538 | seeds
# 9538 | pepper
# 9538 | garlic
# 9538 | milk
# 9538 | root
# 9538 | onion
# 9538 | oil
# 9538 | lentils
# 9538 | tomato
# 9539 | oil
# 9539 | spinach
# 9539 | cumin
# 9539 | pepper
# 9539 | lentils
# 9539 | ginger
# 9539 | parsley
# 9539 | zucchini
# 9539 | tomatoes
# 9539 | carrots
# 9539 | salt
# 9539 | onion
# 9539 | tarragon
# 9539 | broth
# 9540 | water
# 9540 | oil
# 9540 | cumin
# 9540 | curry
# 9540 | onion
# 9540 | tomatoes
# 9540 | lentils
# 9540 | basil
# 9540 | pepper
# 9540 | cardamom
# 9540 | spinach
# 9541 | leaf
# 9541 | salt
# 9541 | pepper
# 9541 | onion
# 9541 | parsley
# 9541 | ham
# 9541 | nutmeg
# 9541 | celery
# 9541 | carrots
# 9541 | sauce
# 9541 | seed
# 9541 | stock
# 9558 | pepper
# 9558 | oil
# 9559 | c
# 9559 | lentils
# 9559 | honey
# 9559 | salt
# 9559 | flour
# 9559 | yeast
# 9559 | oil
# 9560 | lentils
# 9560 | onion
# 9560 | carrots
# 9560 | oil
# 9560 | celery
# 9560 | pepper
# 9560 | mushrooms
# 9560 | thyme
# 9560 | broth
# 9560 | leaf
# 9560 | barley
# 9560 | parsley
# 9560 | sherry
# 9561 | carrot
# 9561 | oil
# 9561 | spinach
# 9561 | leaves
# 9561 | broth
# 9561 | groats
# 9561 | lentils
# 9561 | onion
# 9562 | flakes
# 9562 | leaves
# 9562 | salt
# 9562 | lentils
# 9562 | savory
# 9562 | barley
# 9562 | mushrooms
# 9562 | broth
# 9562 | garlic
# 9562 | pepper
# 9562 | basil
# 9563 | spinach
# 9563 | salt
# 9563 | onions
# 9563 | lentils
# 9563 | oil
# 9563 | juice
# 9563 | mint
# 9564 | turmeric
# 9564 | onions
# 9564 | pasta
# 9564 | mint
# 9564 | parts
# 9564 | stock
# 9564 | parsley
# 9564 | beans
# 9564 | cloves
# 9564 | cilantro
# 9564 | spinach
# 9564 | oil
# 9564 | flour
# 9564 | pepper
# 9564 | lentils
# 9564 | yogurt
# 9564 | onion
# 9565 | nutmeg
# 9565 | onion
# 9565 | liquid
# 9565 | cloves
# 9565 | broth
# 9565 | butter
# 9565 | lentils
# 9565 | wine
# 9566 | celery
# 9566 | cubes
# 9566 | flakes
# 9566 | oil
# 9566 | cumin
# 9566 | cloves
# 9566 | yogurt
# 9566 | tomatoes
# 9566 | coriander
# 9566 | chickpeas
# 9566 | garlic
# 9566 | pepper
# 9566 | onions
# 9566 | leaves
# 9566 | parsley
# 9566 | stock
# 9566 | mint
# 9566 | lentils
# 9566 | cinnamon
# 9566 | zucchini
# 9567 | tomatoes
# 9567 | mix
# 9567 | cheese
# 9567 | lentils
# 9567 | onion
# 9567 | oil
# 9568 | pepper
# 9568 | sugar
# 9568 | lentils
# 9568 | kale
# 9568 | paprika
# 9568 | salt
# 9568 | water
# 9568 | onion
# 9568 | tomato
# 9568 | oil
# 9569 | cloves
# 9569 | cream
# 9569 | lentils
# 9569 | turmeric
# 9569 | root
# 9569 | onion
# 9569 | sugar
# 9569 | water
# 9569 | salt
# 9570 | water
# 9570 | lentils
# 9570 | celery
# 9570 | mustard
# 9570 | salt
# 9570 | vinegar
# 9570 | pepper
# 9570 | cloves
# 9570 | broth
# 9570 | onion
# 9570 | carrots
# 9570 | ham
# 9571 | turmeric
# 9571 | swiss
# 9571 | cumin
# 9571 | coriander
# 9571 | lentils
# 9571 | garlic
# 9571 | oil
# 9571 | bouillon
# 9571 | broth
# 9571 | onions
# 9571 | curry
# 9572 | quinoa
# 9572 | salt
# 9572 | broth
# 9572 | butter
# 9572 | cumin
# 9572 | lentils
# 9572 | chili
# 9572 | pepper
# 9572 | onion
# 9572 | cinnamon
# 9572 | curry
# 9572 | coriander
# 9572 | peas
# 9572 | water
# 9572 | cloves
# 9572 | cardamom
# 9572 | kale
# 9573 | pepper
# 9573 | walnuts
# 9573 | onion
# 9573 | oil
# 9573 | water
# 9573 | lentils
# 9573 | bouillon
# 9574 | cumin
# 9574 | water
# 9574 | oil
# 9574 | pepper
# 9574 | tomato
# 9574 | lentils
# 9574 | cloves
# 9574 | coriander
# 9574 | bouillon
# 9574 | spinach
# 9574 | salt
# 9574 | onion
# 9574 | potatoes
# 9574 | carrots
# 9575 | pepper
# 9575 | tomato
# 9575 | basil
# 9575 | celery
# 9575 | leaf
# 9575 | onion
# 9575 | lentils
# 9575 | cloves
# 9575 | carrots
# 9575 | thyme
# 9575 | ham
# 9575 | water
# 9575 | broth
# 9576 | celery
# 9576 | masala
# 9576 | farro
# 9576 | carrots
# 9576 | onion
# 9576 | oil
# 9576 | broth
# 9576 | lentils
# 9576 | salt
# 9577 | cashews
# 9577 | lentils
# 9577 | coriander
# 9577 | parsley
# 9577 | juice
# 9577 | spinach
# 9577 | pepper
# 9577 | spray
# 9577 | celery
# 9577 | carrots
# 9577 | broth
# 9578 | onion
# 9578 | bragg
# 9578 | carrots
# 9578 | lentils
# 9578 | water
# 9578 | spinach
# 9578 | pepper
# 9578 | salt
# 9578 | celery
# 9579 | cloves
# 9579 | salt
# 9579 | tomato
# 9579 | lentils
# 9579 | water
# 9579 | pepper
# 9579 | oil
# 9579 | onion
# 9579 | cilantro
# 9579 | seeds
# 9579 | spinach
# 9579 | turmeric
# 9580 | spinach
# 9580 | garlic
# 9580 | oil
# 9580 | tops
# 9580 | onion
# 9580 | mushrooms
# 9580 | broth
# 9580 | vinegar
# 9580 | flakes
# 9580 | salt
# 9580 | seasoning
# 9580 | lentils
# 9581 | broth
# 9581 | florets
# 9581 | potato
# 9581 | onion
# 9581 | lentils
# 9581 | oil
# 9581 | celery
# 9581 | rice
# 9582 | asafoetida
# 9582 | dal
# 9582 | pepper
# 9582 | pulp
# 9582 | water
# 9582 | tomato
# 9582 | peppers
# 9582 | seeds
# 9582 | seed
# 9582 | oil
# 9582 | coconut
# 9583 | paprika
# 9583 | milk
# 9583 | ribs
# 9583 | curry
# 9583 | oil
# 9583 | water
# 9583 | turmeric
# 9583 | bouillon
# 9583 | florets
# 9583 | carrots
# 9583 | cumin
# 9583 | flakes
# 9583 | lentils
# 9584 | cumin
# 9584 | sugar
# 9584 | salt
# 9584 | lentils
# 9584 | water
# 9584 | tomato
# 9584 | wine
# 9584 | pepper
# 9584 | carrots
# 9584 | celery
# 9584 | cabbage
# 9584 | tomatoes
# 9584 | garlic
# 9584 | onion
# 9584 | broth
# 9585 | cream
# 9585 | onion
# 9585 | vinegar
# 9585 | water
# 9585 | beets
# 9585 | cabbage
# 9585 | dill
# 9585 | lentils
# 9585 | oil
# 9585 | tomato
# 9585 | potatoes
# 9585 | pepper
# 9585 | carrot
# 9586 | cloves
# 9586 | oil
# 9586 | nutmeg
# 9586 | cumin
# 9586 | cinnamon
# 9586 | salt
# 9586 | pepper
# 9586 | mix
# 9586 | lentils
# 9586 | onion
# 9586 | cabbage
# 9586 | lemon
# 9586 | allspice
# 9586 | carrots
# 9587 | onion
# 9587 | seasoning
# 9587 | mushrooms
# 9587 | tomatoes
# 9587 | water
# 9587 | oil
# 9587 | pepper
# 9587 | garlic
# 9587 | basil
# 9587 | lentils
# 9588 | thyme
# 9588 | oil
# 9588 | salt
# 9588 | stock
# 9588 | mushrooms
# 9588 | onions
# 9588 | lentils
# 9588 | shallot
# 9589 | onion
# 9589 | swiss
# 9589 | broth
# 9589 | mushrooms
# 9589 | quinoa
# 9589 | oil
# 9589 | lentils
# 9590 | oil
# 9590 | pepper
# 9590 | seasoning
# 9590 | lentils
# 9590 | egg
# 9590 | mushrooms
# 9590 | crumbs
# 9590 | salt
# 9590 | mustard
# 9591 | oil
# 9591 | tomato
# 9591 | salt
# 9591 | basil
# 9591 | onion
# 9591 | pepper
# 9591 | caps
# 9591 | lentils
# 9591 | broth
# 9591 | sherry
# 9592 | garlic
# 9592 | mint
# 9592 | shallots
# 9592 | oil
# 9592 | chunks
# 9592 | sauce
# 9592 | pepper
# 9592 | ounce
# 9592 | salt
# 9592 | quinoa
# 9592 | tomatoes
# 9593 | mustard
# 9593 | vinegar
# 9593 | zucchini
# 9593 | carrot
# 9593 | buns
# 9593 | lentils
# 9593 | syrup
# 9593 | sauce
# 9593 | oil
# 9593 | onion
# 9593 | pepper
# 9593 | tomatoes
# 9593 | chili
# 9593 | paste
# 9593 | broth
# 9594 | stalk
# 9594 | garlic
# 9594 | bite
# 9594 | groats
# 9594 | pepper
# 9594 | zucchini
# 9594 | hummus
# 9594 | oil
# 9594 | yeast
# 9594 | lentils
# 9594 | paste
# 9594 | onion
# 9594 | carrots
# 9594 | parsley
# 9594 | broth
# 9594 | potatoes
# 9595 | cumin
# 9595 | oil
# 9595 | ginger
# 9595 | stock
# 9595 | sage
# 9595 | butternut
# 9595 | cinnamon
# 9595 | water
# 9595 | salt
# 9595 | lentils
# 9595 | onion
# 9595 | carrots
# 9596 | seeds
# 9596 | cloves
# 9596 | pepper
# 9596 | celery
# 9596 | kale
# 9596 | salt
# 9596 | lentils
# 9596 | water
# 9596 | paste
# 9596 | lemon
# 9596 | cumin
# 9596 | turmeric
# 9596 | coriander
# 9596 | squash
# 9596 | oil
# 9596 | broth
# 9596 | bouillon
# 9596 | carrot
# 9596 | onion
# 9597 | lentils
# 9597 | onion
# 9597 | turmeric
# 9597 | macaroni
# 9597 | spaghetti
# 9597 | corn
# 9597 | cumin
# 9597 | stock
# 9597 | rice
# 9597 | oil
# 9597 | juice
# 9597 | garlic
# 9598 | cloves
# 9598 | knorr
# 9598 | coriander
# 9598 | butternut
# 9598 | cilantro
# 9598 | stalk
# 9598 | lentils
# 9598 | water
# 9598 | peas
# 9598 | salt
# 9598 | onion
# 9598 | beans
# 9598 | leaves
# 9598 | leaf
# 9598 | cumin
# 9598 | cinnamon
# 9598 | oil
# 9598 | carrot
# 9598 | pepper
# 9599 | oil
# 9599 | squash
# 9599 | cheese
# 9599 | pepper
# 9599 | dressing
# 9599 | water
# 9599 | nuts
# 9599 | beans
# 9600 | cilantro
# 9600 | lentils
# 9600 | juice
# 9600 | salt
# 9600 | tomatoes
# 9600 | avocados
# 9600 | onion
# 9601 | oil
# 9601 | sauce
# 9601 | tomatoes
# 9601 | lentils
# 9601 | peas
# 9601 | pepper
# 9601 | water
# 9601 | carrot
# 9601 | bouillon
# 9601 | onion
# 9601 | paprika
# 9601 | garlic
# 9601 | apple
# 9602 | chili
# 9602 | cumin
# 9602 | allspice
# 9602 | pepper
# 9602 | chocolate
# 9602 | leaf
# 9602 | cloves
# 9602 | salt
# 9602 | cinnamon
# 9603 | lentils
# 9603 | curry
# 9603 | ginger
# 9603 | cloves
# 9603 | onion
# 9603 | yogurt
# 9603 | pepper
# 9603 | thighs
# 9603 | broth
# 9603 | cream
# 9603 | leaf
# 9603 | coriander
# 9603 | cilantro
# 9603 | mustard
# 9603 | celery
# 9603 | salt
# 9603 | flakes
# 9603 | tomato
# 9603 | oil
# 9603 | paste
# 9603 | cumin
# 9603 | carrots
# 9603 | tamarind
# 9603 | masala
# 9603 | potatoes
# 9603 | butter
# 9603 | apples
# 9604 | tarragon
# 9604 | tomatoes
# 9604 | lentils
# 9604 | oil
# 9604 | thyme
# 9604 | leaves
# 9604 | onion
# 9604 | water
# 9604 | lengthwise
# 9604 | broth
# 9604 | paprika
# 9604 | carrots
# 9604 | parsley
# 9604 | cloves
# 9604 | sauce
# 9604 | salt
# 9604 | pepper
# 9605 | pepper
# 9605 | turmeric
# 9605 | potatoes
# 9605 | broth
# 9605 | ground
# 9605 | cloves
# 9605 | tomatoes
# 9605 | oil
# 9605 | carrots
# 9605 | onion
# 9605 | lentils
# 9605 | coriander
# 9605 | water
# 9606 | syrup
# 9606 | yeast
# 9606 | lentils
# 9606 | cinnamon
# 9606 | onion
# 9606 | cumin
# 9606 | milk
# 9606 | stock
# 9606 | tomatoes
# 9606 | root
# 9606 | potatoes
# 9606 | oil
# 9606 | cloves
# 9607 | lentils
# 9607 | chunks
# 9607 | onion
# 9607 | broth
# 9607 | oil
# 9607 | cilantro
# 9607 | masala
# 9607 | pepper
# 9607 | butter
# 9607 | dukka
# 9607 | garlic
# 9607 | spinach
# 9608 | cornstarch
# 9608 | paprika
# 9608 | oil
# 9608 | water
# 9608 | beans
# 9608 | chili
# 9608 | tomatoes
# 9608 | onion
# 9608 | lentils
# 9608 | cumin
# 9608 | salt
# 9608 | quinoa
# 9608 | turmeric
# 9608 | corn
# 9608 | sugar
# 9608 | pepper
# 9608 | flakes
# 9608 | cloves
# 9609 | tomatoes
# 9609 | oil
# 9609 | corn
# 9609 | water
# 9609 | sugar
# 9609 | paprika
# 9609 | onions
# 9609 | cumin
# 9609 | lentils
# 9609 | tomato
# 9609 | beans
# 9610 | chili
# 9610 | pepper
# 9610 | cubes
# 9610 | broth
# 9610 | paprika
# 9610 | chives
# 9610 | lentils
# 9610 | puree
# 9610 | beans
# 9610 | cloves
# 9610 | corn
# 9610 | sugar
# 9610 | onion
# 9610 | oil
# 9611 | tomatoes
# 9611 | paste
# 9611 | turmeric
# 9611 | giblets
# 9611 | water
# 9611 | leaves
# 9611 | oil
# 9611 | chile
# 9611 | salt
# 9611 | peppers
# 9611 | cumin
# 9612 | cloves
# 9612 | lentils
# 9612 | carrots
# 9612 | cumin
# 9612 | onion
# 9612 | pepper
# 9612 | peas
# 9612 | broth
# 9612 | juice
# 9613 | cinnamon
# 9613 | beans
# 9613 | butter
# 9613 | water
# 9613 | hummus
# 9613 | allspice
# 9613 | salt
# 9613 | tartar
# 9613 | ginger
# 9613 | shortening
# 9613 | peas
# 9613 | dough
# 9613 | oil
# 9613 | nutmeg
# 9613 | extract
# 9613 | sugar
# 9613 | lentils
# 9614 | oil
# 9614 | pearl
# 9614 | water
# 9615 | oil
# 9615 | water
# 9615 | lentils
# 9615 | cucumber
# 9615 | zest
# 9615 | onions
# 9615 | parsley
# 9615 | leaf
# 9615 | pepper
# 9615 | honey
# 9615 | tomato
# 9615 | salt
# 9615 | beans
# 9615 | quinoa
# 9615 | vinegar
# 9615 | juice
# 9616 | lemon
# 9616 | mix
# 9616 | lentils
# 9616 | parsley
# 9616 | pepper
# 9616 | cumin
# 9616 | oil
# 9616 | onion
# 9617 | cubes
# 9617 | cloves
# 9617 | onion
# 9617 | tomatoes
# 9617 | oil
# 9617 | herbs
# 9617 | basil
# 9617 | pepper
# 9617 | lentils
# 9617 | nutmeg
# 9617 | broth
# 9617 | wine
# 9617 | paprika
# 9617 | mushrooms
# 9618 | salt
# 9618 | water
# 9618 | lentils
# 9619 | cumin
# 9619 | lentils
# 9619 | salt
# 9619 | juice
# 9619 | garlic
# 9619 | onion
# 9619 | water
# 9619 | greens
# 9619 | cinnamon
# 9619 | oil
# 9620 | tarragon
# 9620 | yogurt
# 9620 | sprigs
# 9620 | halves
# 9620 | salt
# 9620 | link
# 9620 | juice
# 9620 | cumin
# 9620 | cloves
# 9620 | sauce
# 9621 | curry
# 9621 | onion
# 9621 | cumin
# 9621 | turmeric
# 9621 | tomatoes
# 9621 | lentils
# 9621 | oil
# 9621 | pepper
# 9621 | masala
# 9621 | garlic
# 9622 | pepper
# 9622 | coriander
# 9622 | egg
# 9622 | lentils
# 9622 | oil
# 9622 | cilantro
# 9622 | salt
# 9622 | onion
# 9622 | parsley
# 9622 | onions
# 9622 | cumin
# 9623 | potato
# 9623 | spray
# 9623 | allspice
# 9623 | onion
# 9623 | carrot
# 9623 | oil
# 9623 | ribs
# 9623 | garlic
# 9623 | water
# 9623 | lemons
# 9623 | cinnamon
# 9623 | broth
# 9623 | salt
# 9623 | lentils
# 9623 | cumin
# 9623 | tomato
# 9623 | squares
# 9624 | barley
# 9624 | carrots
# 9624 | paste
# 9624 | salt
# 9624 | parsley
# 9624 | cream
# 9624 | onion
# 9624 | wedges
# 9624 | stock
# 9624 | turmeric
# 9624 | oil
# 9624 | lime
# 9624 | pepper
# 9625 | lentils
# 9625 | tomato
# 9625 | butter
# 9625 | onions
# 9625 | pepper
# 9625 | mint
# 9625 | bulgur
# 9625 | leaves
# 9625 | paprika
# 9625 | stock
# 9625 | lemon
# 9626 | asafoetida
# 9626 | ghee
# 9626 | chickpeas
# 9626 | peas
# 9626 | lentils
# 9626 | salt
# 9626 | water
# 9626 | onion
# 9626 | flakes
# 9626 | curry
# 9626 | rice
# 9627 | oil
# 9627 | bread
# 9627 | garlic
# 9627 | ghee
# 9628 | pepper
# 9628 | cream
# 9628 | butter
# 9628 | juice
# 9628 | basil
# 9628 | matoes
# 9629 | water
# 9629 | celery
# 9629 | onion
# 9629 | salt
# 9629 | carrots
# 9629 | leaf
# 9629 | ginger
# 9629 | chicken
# 9630 | water
# 9630 | cheese
# 9630 | cream
# 9630 | mix
# 9630 | peppers
# 9630 | beans
# 9630 | hominy
# 9630 | beef
# 9630 | onion
# 9631 | rings
# 9631 | cloves
# 9631 | sugar
# 9631 | broth
# 9631 | butter
# 9631 | sherry
# 9631 | cheese
# 9631 | salt
# 9631 | leaf
# 9631 | bread
# 9631 | thyme
# 9632 | ham
# 9632 | broth
# 9632 | cloves
# 9632 | parsley
# 9632 | eggs
# 9632 | oil
# 9632 | bread
# 9632 | paprika
# 9632 | pepper
# 9633 | yogurt
# 9633 | flour
# 9634 | apple
# 9634 | sugar
# 9634 | cabbage
# 9634 | seeds
# 9634 | bread
# 9634 | onion
# 9634 | cider
# 9634 | vinegar
# 9634 | bacon
# 9634 | oil
# 9634 | broth
# 9635 | butter
# 9635 | cheese
# 9635 | wine
# 9635 | flour
# 9635 | slices
# 9635 | oil
# 9635 | onions
# 9635 | broth
# 9635 | garlic
# 9635 | salt
# 9635 | thyme
# 9635 | pepper
# 9635 | sherry
# 9636 | cream
# 9636 | beef
# 9636 | flour
# 9636 | sauerkraut
# 9636 | celery
# 9636 | triangles
# 9636 | butter
# 9636 | water
# 9636 | onion
# 9636 | bouillon
# 9636 | cheese
# 9637 | paprika
# 9637 | salt
# 9637 | butter
# 9637 | vinegar
# 9637 | broth
# 9637 | bread
# 9637 | onions
# 9637 | temperature
# 9637 | leaf
# 9637 | leaves
# 9637 | wine
# 9637 | pepper
# 9637 | parsley
# 9637 | sauce
# 9638 | flour
# 9638 | wine
# 9638 | cheese
# 9638 | sugar
# 9638 | onions
# 9638 | baguette
# 9638 | broth
# 9638 | water
# 9638 | butter
# 9639 | cloves
# 9639 | salt
# 9639 | baguette
# 9639 | pesto
# 9639 | cheese
# 9639 | mayonnaise
# 9640 | flour
# 9640 | beer
# 9640 | sugar
# 9640 | salt
# 9641 | water
# 9641 | pepper
# 9641 | eggs
# 9641 | salt
# 9641 | stock
# 9641 | halves
# 9641 | flour
# 9642 | spiralizer
# 9642 | mushrooms
# 9642 | ginger
# 9642 | garlic
# 9642 | water
# 9642 | flakes
# 9642 | oil
# 9642 | peas
# 9642 | cilantro
# 9642 | broth
# 9642 | paste
# 9642 | pepper
# 9642 | lime
# 9642 | salt
# 9642 | choy
# 9642 | scallions
# 9642 | lemongrass
# 9643 | water
# 9643 | vinegar
# 9643 | soy
# 9643 | mushrooms
# 9643 | scallops
# 9643 | ginger
# 9643 | butter
# 9643 | broth
# 9643 | wine
# 9643 | onions
# 9643 | noodles
# 9644 | base
# 9644 | leaves
# 9644 | lemongrass
# 9644 | celery
# 9644 | carrots
# 9644 | onion
# 9644 | peppercorns
# 9644 | chicken
# 9644 | water
# 9644 | noodles
# 9645 | oil
# 9645 | parsley
# 9645 | salt
# 9645 | tomatoes
# 9645 | broth
# 9645 | onion
# 9645 | pepper
# 9645 | cloves
# 9645 | basil
# 9646 | oil
# 9646 | celery
# 9646 | cloves
# 9646 | broth
# 9646 | carrot
# 9646 | tomatoes
# 9646 | thyme
# 9646 | worcestershire
# 9646 | onion
# 9646 | pepper
# 9646 | salt
# 9646 | sauce
# 9647 | broth
# 9647 | onion
# 9647 | sugar
# 9647 | basil
# 9647 | flour
# 9647 | carrots
# 9647 | salt
# 9647 | butter
# 9647 | tomatoes
# 9647 | pepper
# 9647 | milk
# 9648 | soda
# 9648 | broth
# 9648 | sugar
# 9648 | onion
# 9648 | tomatoes
# 9648 | butter
# 9648 | cream
# 9649 | pepper
# 9649 | butter
# 9649 | seed
# 9649 | oil
# 9649 | onion
# 9649 | tomatoes
# 9649 | flakes
# 9649 | water
# 9649 | sugar
# 9649 | cloves
# 9650 | cloves
# 9650 | broth
# 9650 | thyme
# 9650 | tomatoes
# 9650 | paprika
# 9650 | cream
# 9650 | flour
# 9650 | onion
# 9650 | sauce
# 9650 | peppers
# 9650 | sugar
# 9650 | pepper
# 9650 | butter
# 9650 | oil
# 9651 | sugar
# 9651 | egg
# 9651 | soup
# 9651 | cloves
# 9651 | cinnamon
# 9651 | salt
# 9651 | flour
# 9651 | raisins
# 9651 | butter
# 9651 | soda
# 9652 | pepper
# 9652 | sugar
# 9652 | tomatoes
# 9652 | flour
# 9652 | onion
# 9652 | milk
# 9652 | butter
# 9653 | onion
# 9653 | butter
# 9653 | salt
# 9653 | juice
# 9653 | flour
# 9653 | milk
# 9654 | onion
# 9654 | garlic
# 9654 | soup
# 9654 | tomatoes
# 9654 | milk
# 9654 | basil
# 9654 | cheese
# 9654 | water
# 9655 | bacon
# 9655 | celery
# 9655 | onion
# 9655 | wine
# 9655 | leaf
# 9655 | tomatoes
# 9655 | beans
# 9655 | stock
# 9655 | apple
# 9655 | oil
# 9655 | garlic
# 9655 | pepper
# 9656 | tomatoes
# 9656 | flakes
# 9656 | butter
# 9656 | salt
# 9656 | fillet
# 9656 | oil
# 9656 | cloves
# 9657 | peppers
# 9657 | tomato
# 9657 | soup
# 9657 | chips
# 9657 | cheese
# 9658 | leeks
# 9658 | salt
# 9658 | sherry
# 9658 | pepper
# 9658 | broth
# 9658 | cream
# 9658 | butter
# 9658 | chives
# 9658 | oil
# 9658 | garlic
# 9658 | onion
# 9658 | flour
# 9658 | juice
# 9659 | potatoes
# 9659 | milk
# 9659 | broth
# 9659 | cream
# 9659 | cloves
# 9659 | pepper
# 9659 | oil
# 9659 | wine
# 9660 | shallots
# 9660 | leaves
# 9660 | broth
# 9660 | pepper
# 9660 | cream
# 9679 | onion
# 9679 | carrots
# 9679 | oil
# 9679 | half
# 9679 | cloves
# 9680 | onion
# 9680 | curry
# 9680 | oil
# 9680 | broth
# 9680 | carrots
# 9680 | water
# 9681 | butter
# 9681 | basil
# 9681 | flour
# 9681 | flakes
# 9681 | half
# 9681 | broth
# 9681 | pepper
# 9681 | carrots
# 9681 | parsley
# 9681 | salt
# 9682 | pepper
# 9682 | ginger
# 9682 | onion
# 9682 | carrots
# 9682 | oil
# 9682 | broth
# 9682 | curry
# 9682 | potatoes
# 9683 | tomatoes
# 9683 | celery
# 9683 | leaf
# 9683 | thyme
# 9683 | barley
# 9683 | beef
# 9683 | carrots
# 9683 | water
# 9683 | consomme
# 9683 | onion
# 9683 | soup
# 9684 | parsley
# 9684 | sauce
# 9684 | cloves
# 9684 | broth
# 9684 | zucchini
# 9684 | onion
# 9684 | sausage
# 9684 | pasta
# 9684 | peppers
# 9684 | water
# 9684 | wine
# 9684 | carrots
# 9684 | basil
# 9684 | tomatoes
# 9685 | barley
# 9685 | pepper
# 9685 | broth
# 9685 | celery
# 9685 | mushrooms
# 9685 | carrots
# 9685 | garlic
# 9685 | oil
# 9685 | onion
# 9686 | basil
# 9686 | cube
# 9686 | carrots
# 9686 | thyme
# 9686 | water
# 9686 | pepper
# 9686 | celery
# 9686 | tomato
# 9686 | macaroni
# 9686 | garlic
# 9686 | salt
# 9686 | meatballs
# 9687 | carrot
# 9687 | rib
# 9687 | broth
# 9687 | onion
# 9687 | tarragon
# 9687 | oil
# 9687 | wine
# 9688 | broth
# 9688 | thyme
# 9688 | onion
# 9688 | water
# 9688 | tarragon
# 9688 | cream
# 9688 | carrots
# 9688 | cloves
# 9689 | broth
# 9689 | leaf
# 9689 | paprika
# 9689 | peppers
# 9689 | onion
# 9689 | carrots
# 9689 | sauce
# 9689 | pepper
# 9689 | cumin
# 9689 | oil
# 9689 | vinegar
# 9689 | flakes
# 9690 | cinnamon
# 9690 | cumin
# 9690 | onions
# 9690 | ginger
# 9690 | butternut
# 9690 | nutmeg
# 9690 | cream
# 9690 | butter
# 9690 | leeks
# 9690 | ravioli
# 9690 | pepper
# 9690 | broth
# 9690 | wine
# 9691 | onion
# 9691 | half
# 9691 | water
# 9691 | butter
# 9691 | flour
# 9691 | pepper
# 9691 | granules
# 9691 | spinach
# 9692 | flour
# 9692 | potato
# 9692 | oil
# 9692 | cream
# 9692 | juice
# 9692 | onions
# 9692 | broth
# 9692 | spinach
# 9693 | garlic
# 9693 | spinach
# 9693 | scallions
# 9693 | orzo
# 9693 | broth
# 9693 | carrots
# 9693 | pepper
# 9693 | butter
# 9694 | milk
# 9694 | cream
# 9694 | tortellini
# 9694 | seasoning
# 9694 | sausage
# 9694 | spinach
# 9694 | tomatoes
# 9694 | broth
# 9694 | cheese
# 9694 | boursin
# 9695 | stock
# 9695 | leaf
# 9695 | tomato
# 9695 | salt
# 9695 | savory
# 9695 | pepper
# 9695 | onions
# 9695 | sherry
# 9695 | leeks
# 9695 | spinach
# 9695 | butter
# 9695 | cloves
# 9695 | mushrooms
# 9696 | spinach
# 9696 | broth
# 9696 | basil
# 9696 | tortellini
# 9696 | pepper
# 9697 | ounce
# 9697 | pepper
# 9697 | onion
# 9697 | milk
# 9697 | cheese
# 9697 | spinach
# 9697 | garlic
# 9697 | sugar
# 9697 | butter
# 9697 | salt
# 9697 | basil
# 9698 | spinach
# 9698 | pepper
# 9698 | water
# 9698 | shallots
# 9698 | drippings
# 9698 | garlic
# 9698 | broth
# 9698 | onion
# 9698 | leaves
# 9699 | cheese
# 9699 | water
# 9699 | margarine
# 9699 | onion
# 9699 | flour
# 9699 | granules
# 9699 | milk
# 9699 | broccoli
# 9700 | broth
# 9700 | broccoli
# 9700 | flour
# 9700 | cheese
# 9700 | onion
# 9700 | milk
# 9700 | pepper
# 9701 | broth
# 9701 | milk
# 9701 | salt
# 9701 | soup
# 9701 | onion
# 9701 | celery
# 9701 | cheese
# 9701 | water
# 9701 | cornstarch
# 9701 | florets
# 9701 | pepper
# 9702 | pepper
# 9702 | butter
# 9702 | milk
# 9702 | flour
# 9702 | onion
# 9702 | broccoli
# 9702 | velveeta
# 9703 | salt
# 9703 | pepper
# 9703 | butter
# 9703 | milk
# 9703 | broth
# 9703 | broccoli
# 9703 | leeks
# 9703 | coriander
# 9704 | cheese
# 9704 | garlic
# 9704 | florets
# 9704 | cream
# 9704 | butter
# 9704 | salt
# 9704 | stock
# 9704 | pepper
# 9704 | bread
# 9705 | chunks
# 9705 | butter
# 9705 | broth
# 9705 | cheese
# 9705 | flakes
# 9705 | cream
# 9705 | florets
# 9706 | onion
# 9706 | soup
# 9706 | ounces
# 9706 | oil
# 9706 | cheese
# 9706 | broccoli
# 9707 | pepper
# 9707 | juice
# 9707 | broccoli
# 9707 | salt
# 9707 | broth
# 9707 | oil
# 9707 | cheese
# 9707 | onion
# 9707 | cloves
# 9708 | pepper
# 9708 | cheese
# 9708 | nutmeg
# 9708 | cream
# 9708 | salt
# 9708 | broth
# 9708 | crosswise
# 9708 | onion
# 9708 | broccoli
# 9708 | butter
# 9709 | florets
# 9709 | oil
# 9709 | cream
# 9709 | broth
# 9709 | water
# 9709 | pepper
# 9709 | leaf
# 9709 | shallots
# 9709 | thyme
# 9710 | pepper
# 9710 | slices
# 9710 | cauliflower
# 9710 | stock
# 9710 | curry
# 9710 | butter
# 9710 | onion
# 9710 | oil
# 9710 | tapatio
# 9711 | almonds
# 9711 | stock
# 9711 | oil
# 9711 | florets
# 9711 | cumin
# 9711 | salt
# 9711 | coriander
# 9711 | skin
# 9711 | butter
# 9711 | half
# 9711 | pepper
# 9711 | garlic
# 9711 | turmeric
# 9712 | broth
# 9712 | cheese
# 9712 | milk
# 9712 | pepper
# 9712 | onion
# 9712 | flour
# 9712 | florets
# 9712 | butter
# 9713 | half
# 9713 | cloves
# 9713 | thyme
# 9713 | broth
# 9713 | celery
# 9713 | florets
# 9713 | cream
# 9713 | potatoes
# 9713 | butter
# 9713 | milk
# 9713 | cheese
# 9713 | parsley
# 9713 | pepper
# 9713 | onion
# 9714 | broth
# 9714 | half
# 9714 | cheese
# 9714 | bacon
# 9714 | curry
# 9714 | pepper
# 9714 | florets
# 9714 | chunks
# 9714 | sherry
# 9714 | oil
# 9714 | squash
# 9715 | oil
# 9715 | ginger
# 9715 | onion
# 9715 | salt
# 9715 | stock
# 9715 | florets
# 9715 | pepper
# 9716 | milk
# 9716 | broth
# 9716 | butter
# 9716 | florets
# 9716 | flour
# 9716 | pepper
# 9716 | oil
# 9716 | onion
# 9716 | seeds
# 9717 | broth
# 9717 | garlic
# 9717 | salt
# 9717 | oil
# 9717 | corn
# 9717 | florets
# 9717 | onion
# 9718 | tomatoes
# 9718 | water
# 9718 | cloves
# 9718 | oil
# 9718 | onion
# 9718 | granules
# 9718 | cabbage
# 9718 | pepper
# 9718 | salt
# 9719 | water
# 9719 | sauce
# 9719 | sugar
# 9719 | oil
# 9719 | vinegar
# 9719 | juice
# 9719 | beef
# 9719 | pepper
# 9719 | cabbage
# 9719 | onion
# 9719 | salt
# 9720 | onions
# 9720 | leaf
# 9720 | water
# 9720 | peppercorns
# 9720 | beef
# 9720 | leaves
# 9720 | carrots
# 9721 | bouillon
# 9721 | beef
# 9721 | water
# 9721 | rice
# 9721 | pepper
# 9721 | soup
# 9721 | butter
# 9721 | ounce
# 9721 | size
# 9721 | onion
# 9722 | pepper
# 9722 | cloves
# 9722 | broth
# 9722 | cabbage
# 9722 | tomatoes
# 9722 | bacon
# 9722 | onion
# 9723 | butter
# 9723 | onion
# 9723 | peppers
# 9723 | cream
# 9723 | cloves
# 9723 | pepper
# 9723 | broth
# 9724 | rice
# 9724 | pepper
# 9724 | cube
# 9724 | sugar
# 9724 | tomatoes
# 9724 | tomato
# 9724 | beef
# 9724 | sauce
# 9724 | salt
# 9725 | parsley
# 9725 | beef
# 9725 | cinnamon
# 9725 | sugar
# 9725 | garlic
# 9725 | pepper
# 9725 | rice
# 9725 | oil
# 9725 | tomatoes
# 9725 | celery
# 9725 | salt
# 9725 | water
# 9725 | juice
# 9725 | onion
# 9726 | peppers
# 9726 | pepper
# 9726 | oil
# 9726 | onion
# 9726 | broth
# 9726 | garlic
# 9726 | beans
# 9727 | celery
# 9727 | salt
# 9727 | oil
# 9727 | carrots
# 9727 | cloves
# 9727 | thyme
# 9727 | peppers
# 9727 | broth
# 9727 | rice
# 9727 | flakes
# 9727 | onions
# 9727 | pepper
# 9728 | tomato
# 9728 | sugar
# 9728 | pepper
# 9728 | peppers
# 9728 | garlic
# 9728 | salt
# 9728 | water
# 9728 | base
# 9728 | beef
# 9728 | ketchup
# 9728 | juice
# 9728 | oil
# 9728 | onion
# 9728 | rice
# 9729 | lemon
# 9729 | thyme
# 9729 | pepper
# 9729 | broth
# 9729 | salt
# 9729 | seed
# 9730 | parsley
# 9730 | onion
# 9730 | bacon
# 9730 | leaf
# 9730 | onions
# 9730 | pepper
# 9730 | celery
# 9730 | sugar
# 9730 | carrots
# 9730 | broth
# 9730 | sauce
# 9730 | liquid
# 9730 | cloves
# 9746 | flour
# 9746 | base
# 9746 | water
# 9746 | pepper
# 9746 | mushrooms
# 9747 | wine
# 9747 | spinach
# 9747 | sauce
# 9747 | cloves
# 9747 | tops
# 9747 | linguine
# 9747 | ginger
# 9747 | breast
# 9747 | discard
# 9747 | broth
# 9747 | pepper
# 9747 | wedges
# 9747 | carrots
# 9748 | bouillon
# 9748 | sherry
# 9748 | mushrooms
# 9748 | flour
# 9748 | broth
# 9748 | cream
# 9748 | butter
# 9749 | mushrooms
# 9749 | cream
# 9749 | pepper
# 9749 | oil
# 9749 | thyme
# 9749 | milk
# 9749 | butter
# 9749 | onions
# 9749 | broth
# 9749 | salt
# 9750 | flour
# 9750 | sauce
# 9750 | sherry
# 9750 | thyme
# 9750 | pepper
# 9750 | cloves
# 9750 | salt
# 9750 | broth
# 9750 | onion
# 9750 | butter
# 9750 | cream
# 9750 | mushrooms
# 9751 | mushrooms
# 9751 | sauce
# 9751 | milk
# 9751 | paprika
# 9751 | tomato
# 9751 | dill
# 9751 | butter
# 9751 | broth
# 9751 | onions
# 9751 | pepper
# 9751 | salt
# 9751 | cream
# 9751 | flour
# 9752 | margarine
# 9752 | onion
# 9752 | wine
# 9752 | celery
# 9752 | cream
# 9752 | flour
# 9752 | bouillon
# 9752 | milk
# 9752 | soup
# 9752 | zucchini
# 9752 | carrots
# 9752 | water
# 9753 | slices
# 9753 | stock
# 9753 | onion
# 9753 | oil
# 9753 | salt
# 9753 | curry
# 9754 | oil
# 9754 | weed
# 9754 | garlic
# 9754 | zucchini
# 9754 | tarragon
# 9754 | onion
# 9754 | pepper
# 9754 | tomatoes
# 9754 | broth
# 9754 | salt
# 9755 | butter
# 9755 | zucchini
# 9755 | flour
# 9755 | pepper
# 9755 | water
# 9755 | onion
# 9755 | basil
# 9755 | salt
# 9755 | milk
# 9756 | oil
# 9756 | basil
# 9756 | mint
# 9756 | juice
# 9756 | cornstarch
# 9756 | onion
# 9756 | tomato
# 9756 | zucchini
# 9756 | water
# 9756 | pepper
# 9757 | broth
# 9757 | butter
# 9757 | zucchini
# 9757 | pepper
# 9757 | weed
# 9757 | wheat
# 9757 | onion
# 9757 | cheese
# 9757 | vinegar
# 9758 | onion
# 9758 | oil
# 9758 | salt
# 9758 | cloves
# 9758 | potato
# 9758 | water
# 9758 | broth
# 9758 | almonds
# 9758 | zucchini
# 9759 | chunks
# 9759 | cilantro
# 9759 | pepper
# 9759 | cream
# 9759 | peppers
# 9759 | salt
# 9759 | onions
# 9759 | cheese
# 9760 | campbell
# 9760 | zucchini
# 9760 | pepper
# 9760 | tomatoes
# 9760 | sugar
# 9760 | celery
# 9760 | onion
# 9760 | salt
# 9761 | butter
# 9761 | pepper
# 9761 | broth
# 9761 | cream
# 9761 | zucchinis
# 9761 | onion
# 9761 | garlic
# 9761 | water
# 9762 | cinnamon
# 9762 | sticks
# 9762 | coriander
# 9762 | cilantro
# 9762 | cardamom
# 9762 | onion
# 9762 | zucchini
# 9762 | stock
# 9762 | cumin
# 9762 | turmeric
# 9762 | butter
# 9762 | pepper
# 9762 | salt
# 9762 | seeds
# 9762 | ginger
# 9763 | oil
# 9763 | zucchini
# 9763 | carrot
# 9763 | pepper
# 9763 | water
# 9763 | shallot
# 9763 | garlic
# 9763 | bouillon
# 9763 | parsley
# 9763 | leaves
# 9763 | potato
# 9764 | sugar
# 9764 | ginger
# 9764 | milk
# 9764 | cream
# 9764 | thyme
# 9764 | onion
# 9764 | broth
# 9764 | pepper
# 9764 | squash
# 9764 | butter
# 9765 | allspice
# 9765 | cumin
# 9765 | butter
# 9765 | pepper
# 9765 | onion
# 9765 | cubes
# 9765 | bouillon
# 9765 | broth
# 9765 | thyme
# 9766 | squash
# 9766 | onion
# 9766 | honey
# 9766 | salt
# 9766 | butter
# 9766 | pepper
# 9766 | oil
# 9766 | broth
# 9766 | cream
# 9766 | nutmeg
# 9767 | onion
# 9767 | cinnamon
# 9767 | butter
# 9767 | parsley
# 9767 | pepper
# 9767 | sugar
# 9767 | squash
# 9767 | cheese
# 9767 | broth
# 9768 | spaghetti
# 9768 | butter
# 9768 | onion
# 9768 | broth
# 9768 | root
# 9768 | sherry
# 9768 | apples
# 9768 | squash
# 9768 | pepper
# 9768 | curry
# 9769 | buttercup
# 9769 | marjoram
# 9769 | butter
# 9769 | pepper
# 9769 | onion
# 9769 | cheese
# 9769 | basil
# 9769 | broth
# 9770 | garlic
# 9770 | pepper
# 9770 | squash
# 9770 | sugar
# 9770 | curry
# 9770 | parsley
# 9770 | nutmeg
# 9770 | yogurt
# 9770 | cinnamon
# 9770 | broth
# 9770 | onions
# 9770 | leaf
# 9771 | tarragon
# 9771 | cheese
# 9771 | squash
# 9771 | cream
# 9771 | juice
# 9771 | stock
# 9771 | zucchini
# 9771 | pepper
# 9771 | salt
# 9772 | salt
# 9772 | onion
# 9772 | paprika
# 9772 | broth
# 9772 | squash
# 9772 | cream
# 9772 | carrot
# 9772 | juice
# 9772 | paste
# 9772 | oil
# 9772 | pepitas
# 9772 | parsley
# 9772 | pepper
# 9773 | stock
# 9773 | wine
# 9773 | lime
# 9773 | onion
# 9773 | pepper
# 9773 | celery
# 9773 | avocados
# 9773 | bacon
# 9773 | cream
# 9774 | cheese
# 9774 | onion
# 9774 | mix
# 9774 | avocados
# 9774 | beans
# 9774 | corn
# 9774 | rotel
# 9774 | tomato
# 9774 | beef
# 9774 | broth
# 9775 | rings
# 9775 | broth
# 9775 | lime
# 9775 | meat
# 9775 | strips
# 9775 | onion
# 9775 | garlic
# 9775 | tomatoes
# 9776 | broth
# 9776 | avocado
# 9776 | chips
# 9776 | pepper
# 9776 | mix
# 9776 | corn
# 9776 | tomatoes
# 9776 | cumin
# 9776 | cloves
# 9776 | cheese
# 9776 | oil
# 9776 | peppers
# 9777 | broth
# 9777 | avocados
# 9777 | strips
# 9777 | tomatoes
# 9777 | sauce
# 9777 | onion
# 9777 | leaves
# 9777 | salt
# 9777 | oil
# 9778 | pepper
# 9778 | garlic
# 9778 | onion
# 9778 | kernels
# 9778 | half
# 9778 | sauce
# 9778 | avocados
# 9778 | shrimp
# 9778 | broth
# 9778 | juice
# 9778 | yogurt
# 9779 | sage
# 9779 | thyme
# 9779 | celery
# 9779 | stock
# 9779 | salt
# 9779 | cider
# 9779 | parts
# 9779 | cubes
# 9779 | bacon
# 9779 | apples
# 9779 | butter
# 9779 | carrots
# 9780 | water
# 9780 | root
# 9780 | squash
# 9780 | pepper
# 9780 | cider
# 9780 | potato
# 9780 | butter
# 9780 | onion
# 9780 | sugar
# 9780 | pecans
# 9780 | apples
# 9780 | yogurt
# 9781 | pepper
# 9781 | lengthwise
# 9781 | nutmeg
# 9781 | apples
# 9781 | broth
# 9781 | oil
# 9781 | cider
# 9781 | onion
# 9781 | garlic
# 9781 | chunks
# 9781 | celery
# 9782 | shallots
# 9782 | stock
# 9782 | lengthwise
# 9782 | apples
# 9782 | butter
# 9783 | oil
# 9783 | cheese
# 9783 | salt
# 9783 | leaf
# 9783 | thyme
# 9783 | wine
# 9783 | shallot
# 9783 | smith
# 9783 | juice
# 9783 | pepper
# 9783 | stock
# 9783 | bulb
# 9784 | water
# 9784 | apples
# 9784 | onion
# 9784 | butter
# 9784 | stock
# 9784 | honey
# 9784 | oil
# 9784 | cider
# 9784 | lengthwise
# 9784 | sugar
# 9784 | thyme
# 9784 | squashes
# 9785 | vinegar
# 9785 | slices
# 9785 | crosswise
# 9785 | stock
# 9785 | oil
# 9785 | rosemary
# 9786 | pears
# 9786 | margarine
# 9786 | leaf
# 9786 | sage
# 9786 | pepper
# 9786 | ginger
# 9786 | parsley
# 9786 | apples
# 9786 | broth
# 9787 | celery
# 9787 | potatoes
# 9787 | onion
# 9787 | oil
# 9787 | apples
# 9787 | spice
# 9787 | broth
# 9787 | salt
# 9788 | butter
# 9788 | ounce
# 9788 | onion
# 9788 | broth
# 9788 | apples
# 9788 | water
# 9788 | garlic
# 9788 | sugar
# 9788 | cumin
# 9788 | curry
# 9789 | chardonnay
# 9789 | bacon
# 9789 | cream
# 9789 | onions
# 9789 | pepper
# 9789 | potato
# 9789 | carrots
# 9789 | apple
# 9789 | butter
# 9789 | sugar
# 9789 | spice
# 9789 | cubes
# 9789 | organic
# 9790 | cinnamon
# 9790 | dice
# 9790 | cloves
# 9790 | oil
# 9790 | sugar
# 9790 | carton
# 9790 | chips
# 9790 | butter
# 9790 | ginger
# 9790 | pepper
# 9790 | chunks
# 9790 | milk
# 9791 | basil
# 9791 | pepper
# 9791 | wine
# 9791 | paprika
# 9791 | cream
# 9791 | leaf
# 9791 | fraiche
# 9791 | butter
# 9791 | thyme
# 9791 | stock
# 9791 | peppers
# 9791 | onion
# 9791 | carrot
# 9791 | zest
# 9791 | tomatoes
# 9792 | rutabagas
# 9792 | sprigs
# 9792 | chunks
# 9792 | oil
# 9792 | pepper
# 9792 | vinegar
# 9792 | spray
# 9792 | salt
# 9792 | parsnips
# 9792 | stock
# 9792 | potatoes
# 9793 | cardamom
# 9793 | strawberries
# 9793 | sugar
# 9793 | water
# 9793 | yogurt
# 9793 | juice
# 9794 | cantaloupe
# 9794 | juice
# 9794 | cinnamon
# 9795 | cream
# 9795 | butter
# 9795 | onion
# 9795 | broth
# 9795 | cubes
# 9795 | pepper
# 9796 | onion
# 9796 | grease
# 9796 | sugar
# 9796 | potato
# 9796 | cinnamon
# 9796 | pepper
# 9796 | leaves
# 9796 | carrots
# 9796 | half
# 9796 | juice
# 9796 | flakes
# 9796 | butter
# 9796 | paste
# 9796 | stock
# 9797 | butter
# 9797 | broth
# 9797 | carrots
# 9797 | oranges
# 9797 | pepper
# 9797 | root
# 9797 | flour
# 9797 | nuts
# 9797 | onions
# 9797 | fraiche
# 9798 | melon
# 9798 | sugar
# 9798 | juice
# 9798 | blueberries
# 9798 | pineapple
# 9798 | oranges
# 9798 | yogurt
# 9798 | leaves
# 9798 | zest
# 9799 | water
# 9799 | garlic
# 9799 | pasta
# 9799 | pepper
# 9799 | potatoes
# 9799 | broth
# 9799 | carrots
# 9799 | onion
# 9799 | soup
# 9799 | oil
# 9799 | celery
# 9799 | basil
# 9800 | paprika
# 9800 | salt
# 9800 | oil
# 9800 | pepper
# 9800 | potatoes
# 9800 | bouillon
# 9800 | cloves
# 9800 | cream
# 9800 | onion
# 9800 | juice
# 9800 | water
# 9801 | broth
# 9801 | pepper
# 9801 | onion
# 9801 | oil
# 9801 | wine
# 9801 | carrots
# 9801 | vinegar
# 9801 | persimmons
# 9801 | butternut
# 9801 | leaf
# 9802 | broth
# 9802 | nutmeg
# 9802 | pepper
# 9802 | ginger
# 9802 | half
# 9802 | pecans
# 9802 | potatoes
# 9802 | cinnamon
# 9802 | cointreau
# 9803 | honey
# 9803 | lime
# 9803 | coriander
# 9803 | garlic
# 9803 | celery
# 9803 | oil
# 9803 | stock
# 9803 | onion
# 9803 | salt
# 9803 | sugar
# 9803 | pumpkin
# 9803 | curry
# 9803 | cinnamon
# 9803 | nutmeg
# 9803 | pepper
# 9803 | milk
# 9803 | carrot
# 9803 | banana
# 9804 | milk
# 9804 | peas
# 9804 | beans
# 9804 | juice
# 9804 | water
# 9805 | dill
# 9805 | flour
# 9805 | peppers
# 9805 | salt
# 9805 | yogurt
# 9805 | cilantro
# 9805 | lemons
# 9805 | cabbage
# 9805 | spinach
# 9805 | celery
# 9806 | bananas
# 9806 | sugar
# 9806 | tapioca
# 9806 | salt
# 9806 | water
# 9806 | milk
# 9807 | beans
# 9807 | tomatoes
# 9807 | spinach
# 9807 | seeds
# 9807 | chickpeas
# 9807 | breast
# 9807 | leaf
# 9807 | salt
# 9807 | broth
# 9807 | onion
# 9807 | goya
# 9807 | parsley
# 9807 | oil
# 9807 | peppercorns
# 9807 | garlic
# 9807 | rice
# 9808 | cubes
# 9808 | water
# 9808 | almonds
# 9808 | cucumbers
# 9808 | oil
# 9808 | grapes
# 9808 | vinegar
# 9808 | salt
# 9808 | fraiche
# 9808 | pepper
# 9808 | crosswise
# 9809 | onion
# 9809 | celery
# 9809 | leek
# 9809 | pineapple
# 9809 | oil
# 9809 | curry
# 9809 | pepper
# 9809 | butter
# 9809 | tomatoes
# 9809 | salt
# 9809 | water
# 9809 | garlic
# 9809 | cream
# 9809 | cumin
# 9810 | water
# 9810 | juice
# 9810 | mangoes
# 9810 | sugar
# 9810 | pineapple
# 9811 | carrot
# 9811 | oil
# 9811 | cornstarch
# 9811 | pepper
# 9811 | vinegar
# 9811 | water
# 9811 | cubes
# 9811 | sauce
# 9811 | juice
# 9811 | sugar
# 9811 | soup
# 9811 | chunks
# 9812 | tomatoes
# 9812 | cheese
# 9812 | soup
# 9812 | rice
# 9812 | parsley
# 9812 | basil
# 9812 | onions
# 9812 | pineapple
# 9812 | oil
# 9812 | noodles
# 9812 | pepper
# 9812 | coconut
# 9812 | broth
# 9812 | almonds
# 9812 | cubes
# 9813 | half
# 9813 | sugar
# 9813 | mango
# 9813 | lemon
# 9814 | honey
# 9814 | limes
# 9814 | melon
# 9814 | cinnamon
# 9814 | ginger
# 9814 | milk
# 9815 | melon
# 9815 | cookies
# 9815 | blueberries
# 9816 | cucumber
# 9816 | vinegar
# 9816 | onion
# 9816 | avocado
# 9816 | melon
# 9816 | garlic
# 9816 | pepper
# 9816 | juice
# 9817 | paprika
# 9817 | nutmeg
# 9817 | syrup
# 9817 | juice
# 9817 | ginger
# 9817 | onions
# 9817 | salt
# 9817 | coriander
# 9817 | oil
# 9817 | flakes
# 9817 | celery
# 9817 | cinnamon
# 9817 | yam
# 9817 | carrots
# 9817 | cloves
# 9817 | allspice
# 9817 | water
# 9817 | cumin
# 9817 | squash
# 9818 | carrots
# 9818 | oil
# 9818 | celery
# 9818 | pepper
# 9818 | dill
# 9818 | stock
# 9818 | barley
# 9818 | breast
# 9818 | parsnips
# 9818 | onion
# 9818 | potatoes
# 9819 | cloves
# 9819 | celery
# 9819 | pepper
# 9819 | potatoes
# 9819 | onion
# 9819 | beans
# 9819 | seasoning
# 9819 | tomatoes
# 9819 | broth
# 9819 | carrots
# 9819 | oil
# 9820 | broth
# 9820 | syrup
# 9820 | pepper
# 9820 | cloves
# 9820 | leaves
# 9820 | thyme
# 9820 | stick
# 9820 | salt
# 9820 | potato
# 9820 | oil
# 9820 | squash
# 9820 | sage
# 9821 | nutmeg
# 9821 | squash
# 9821 | garlic
# 9821 | potatoes
# 9821 | half
# 9821 | oil
# 9821 | apples
# 9821 | cinnamon
# 9821 | cumin
# 9821 | ginger
# 9821 | pepper
# 9821 | yogurt
# 9821 | onion
# 9821 | salt
# 9821 | broth
# 9822 | onion
# 9822 | potatoes
# 9822 | milk
# 9822 | broth
# 9822 | cilantro
# 9822 | juice
# 9822 | root
# 9822 | oil
# 9822 | paste
# 9822 | salt
# 9823 | dice
# 9823 | peanuts
# 9823 | butter
# 9823 | ginger
# 9823 | sugar
# 9823 | oil
# 9823 | milk
# 9823 | chunks
# 9823 | pepper
# 9823 | cloves
# 9823 | nutmeg
# 9823 | carton
# 9824 | squash
# 9824 | cloves
# 9824 | carrot
# 9824 | nutmeg
# 9824 | stock
# 9824 | pepper
# 9824 | butter
# 9824 | potato
# 9824 | cinnamon
# 9824 | stalk
# 9824 | onion
# 9824 | turnip
# 9825 | salt
# 9825 | water
# 9825 | cloves
# 9825 | carrot
# 9825 | butter
# 9825 | coriander
# 9825 | pepper
# 9825 | potatoes
# 9825 | cilantro
# 9825 | cinnamon
# 9825 | onion
# 9825 | oil
# 9825 | peanuts
# 9825 | cumin
# 9825 | tomatoes
# 9825 | root
# 9826 | broth
# 9826 | egg
# 9826 | water
# 9826 | cornstarch
# 9826 | corn
# 9827 | corn
# 9827 | garlic
# 9827 | butter
# 9827 | salt
# 9827 | pepper
# 9827 | milk
# 9827 | cheese
# 9827 | parsley
# 9827 | flour
# 9827 | onion
# 9827 | broth
# 9828 | pepper
# 9828 | meat
# 9828 | half
# 9828 | corn
# 9828 | parsley
# 9828 | salt
# 9828 | milk
# 9828 | butter
# 9828 | sauce
# 9828 | flour
# 9828 | onions
# 9829 | butter
# 9829 | creole
# 9829 | crawfish
# 9829 | corn
# 9829 | sauce
# 9829 | onion
# 9829 | soup
# 9829 | flour
# 9829 | worcestershire
# 9829 | milk
# 9829 | salt
# 9830 | parsley
# 9830 | onion
# 9830 | butter
# 9830 | cream
# 9830 | pepper
# 9830 | corn
# 9830 | flour
# 9831 | corn
# 9831 | broth
# 9831 | oil
# 9831 | shallots
# 9831 | cream
# 9831 | pepper
# 9831 | salt
# 9832 | beans
# 9832 | celery
# 9832 | water
# 9832 | pepper
# 9832 | oil
# 9832 | bouillon
# 9832 | hominy
# 9832 | rutabaga
# 9832 | carrots
# 9832 | cubes
# 9833 | pepper
# 9833 | salt
# 9833 | kernels
# 9833 | water
# 9833 | butter
# 9834 | squash
# 9834 | stock
# 9834 | yogurt
# 9834 | pepper
# 9834 | onion
# 9834 | oil
# 9834 | basil
# 9834 | nutmeg
# 9834 | corn
# 9834 | garlic
# 9835 | milk
# 9835 | carton
# 9835 | leaves
# 9835 | butter
# 9835 | pepper
# 9835 | cloves
# 9835 | sugar
# 9835 | corn
# 9835 | oil
# 9835 | cumin
# 9835 | dice
# 9836 | salsa
# 9836 | fajita
# 9836 | broth
# 9836 | cumin
# 9836 | half
# 9836 | onion
# 9836 | soup
# 9836 | cheese
# 9836 | halves
# 9836 | cilantro
# 9836 | chips
# 9836 | flour
# 9836 | corn
# ...
# 9868 | tahini
# 9869 | salt
# 9869 | onions
# 9869 | nutmeg
# 9869 | half
# 9869 | stock
# 9869 | milk
# 9869 | cumin
# 9869 | coriander
# 9869 | ginger
# 9869 | cubes
# 9869 | potato
# 9869 | oil
# 9869 | pepper
# 9869 | allspice
# 9870 | water
# 9870 | knuckle
# 9870 | leaves
# 9870 | onion
# 9870 | salt
# 9870 | celery
# 9870 | roots
# 9870 | pepper
# 9870 | vinegar
# 9870 | crosswise
# 9871 | onion
# 9871 | broth
# 9871 | soup
# 9871 | beer
# 9871 | brisket
# 9872 | broth
# 9872 | brisket
# 9872 | mix
# 9872 | rolls
# 9873 | pepper
# 9873 | chops
# 9873 | soup
# 9873 | water
# 9873 | onion
# 9873 | bouillon
# 9874 | mushrooms
# 9874 | wine
# 9874 | water
# 9874 | soup
# 9874 | pepper
# 9874 | chops
# 9875 | mix
# 9875 | oil
# 9875 | chops
# 9875 | flour
# 9876 | chops
# 9876 | sauce
# 9876 | sugar
# 9876 | soup
# 9877 | flour
# 9877 | water
# 9877 | bragg
# 9877 | garlic
# 9877 | pepper
# 9877 | oil
# 9877 | chops
# 9877 | soup
# 9877 | wine
# 9878 | butter
# 9878 | soup
# 9878 | pepper
# 9878 | water
# 9878 | chops
# 9878 | milk
# 9879 | soup
# 9879 | onion
# 9879 | salt
# 9879 | chops
# 9879 | pepper
# 9879 | mushrooms
# 9880 | mix
# 9880 | chops
# 9880 | salad
# 9880 | apricot
# 9881 | broth
# 9881 | potatoes
# 9881 | sausage
# 9881 | thyme
# 9881 | onion
# 9881 | cider
# 9881 | pepper
# 9881 | sauerkraut
# 9881 | celery
# 9881 | garlic
# 9882 | onion
# 9882 | cornstarch
# 9882 | water
# 9882 | spareribs
# 9882 | sugar
# 9882 | soup
# 9882 | sauce
# 9882 | soy
# 9883 | parsnips
# 9883 | cheese
# 9883 | thyme
# 9883 | parsley
# 9883 | leaves
# 9883 | garlic
# 9883 | butter
# 9883 | carrots
# 9883 | paprika
# 9883 | bread
# 9883 | pepper
# 9883 | tabasco
# 9883 | sherry
# 9883 | ribs
# 9883 | onions
# 9883 | water
# 9883 | oil
# 9883 | provence
# 9883 | wine
# 9883 | flour
# 9883 | salt
# 9884 | salt
# 9884 | ribs
# 9884 | pepper
# 9884 | paprika
# 9884 | broth
# 9884 | onions
# 9884 | seasoning
# 9884 | bread
# 9884 | cheese
# 9884 | butter
# 9885 | cloves
# 9885 | oil
# 9885 | cream
# 9885 | salt
# 9885 | pepper
# 9885 | onions
# 9885 | chunks
# 9885 | florets
# 9885 | parts
# 9885 | shallots
# 9885 | stock
# 9885 | carrots
# 9885 | potatoes
# 9886 | yolk
# 9886 | pastry
# 9886 | seeds
# 9887 | spaghetti
# 9887 | sauce
# 9887 | carrots
# 9887 | salmon
# 9887 | juice
# 9887 | root
# 9887 | water
# 9887 | leaves
# 9887 | potatoes
# 9887 | onion
# 9887 | squares
# 9887 | pepper
# 9888 | butter
# 9888 | cheese
# 9888 | onion
# 9888 | potatoes
# 9888 | juice
# 9888 | pepper
# 9888 | gravlax
# 9888 | broth
# 9888 | chives
# 9889 | paste
# 9889 | garlic
# 9889 | lengthwise
# 9889 | pepper
# 9889 | onions
# 9889 | potatoes
# 9889 | butter
# 9889 | salt
# 9889 | water
# 9889 | bacon
# 9889 | fillets
# 9889 | mustard
# 9889 | oil
# 9889 | onion
# 9890 | salt
# 9890 | pepper
# 9890 | butter
# 9890 | onions
# 9890 | milk
# 9890 | soup
# 9890 | ounce
# 9890 | macaroni
# 9890 | cheese
# 9891 | ounce
# 9891 | peas
# 9891 | soup
# 9891 | mix
# 9892 | milk
# 9892 | cheese
# 9892 | noodles
# 9892 | ounce
# 9892 | peas
# 9892 | soup
# 9892 | butter
# 9893 | milk
# 9893 | bread
# 9893 | ounce
# 9893 | pepper
# 9893 | soup
# 9894 | soup
# 9894 | ounce
# 9894 | eggs
# 9894 | bread
# 9895 | soup
# 9895 | noodles
# 9895 | onion
# 9895 | ounce
# 9895 | cream
# 9895 | oil
# 9896 | soup
# 9896 | butter
# 9896 | salt
# 9896 | milk
# 9896 | tuna
# 9896 | crumbs
# 9896 | thyme
# 9896 | pepper
# 9896 | pasta
# 9896 | mushrooms
# 9897 | juice
# 9897 | milk
# 9897 | mayonnaise
# 9897 | salt
# 9897 | soup
# 9897 | parsley
# 9897 | cheese
# 9897 | pasta
# 9897 | pepper
# 9897 | ounce
# 9897 | crumbs
# 9897 | cream
# 9898 | mushrooms
# 9898 | flour
# 9898 | onion
# 9898 | butter
# 9898 | wine
# 9898 | salt
# 9898 | pepper
# 9898 | scallops
# 9898 | milk
# 9898 | parsley
# 9898 | cheese
# 9899 | potatoes
# 9899 | ham
# 9899 | pepper
# 9899 | cheese
# 9899 | broth
# 9899 | garlic
# 9900 | dice
# 9900 | soup
# 9900 | butter
# 9900 | ginger
# 9900 | turmeric
# 9900 | oil
# 9900 | threads
# 9900 | pepper
# 9900 | milk
# 9900 | florets
# 9900 | cloves
# 9900 | carton
# 9900 | sugar
# 9901 | soup
# 9901 | blend
# 9901 | slices
# 9901 | potatoes
# 9901 | milk
# 9901 | onion
# 9902 | flour
# 9902 | roe
# 9902 | pepper
# 9902 | onion
# 9902 | milk
# 9902 | mace
# 9902 | crabmeat
# 9902 | sherry
# 9903 | worcestershire
# 9903 | pepper
# 9903 | flour
# 9903 | crabmeat
# 9903 | milk
# 9903 | onion
# 9903 | salt
# 9903 | butter
# 9903 | cream
# 9904 | cream
# 9904 | sherry
# 9904 | butter
# 9904 | parsley
# 9904 | pepper
# 9904 | salt
# 9904 | flour
# 9904 | onion
# 9904 | worcestershire
# 9904 | roe
# 9904 | crabmeat
# 9904 | mace
# 9904 | milk
# 9905 | cream
# 9905 | wine
# 9905 | pepper
# 9905 | onion
# 9905 | cloves
# 9905 | milk
# 9905 | butter
# 9905 | thyme
# 9905 | salt
# 9905 | granules
# 9905 | flour
# 9905 | broth
# 9905 | parsley
# 9905 | mushrooms
# 9906 | cloves
# 9906 | pepper
# 9906 | onion
# 9906 | ginger
# 9906 | zest
# 9906 | chicken
# 9906 | celery
# 9906 | noodles
# 9906 | sauce
# 9906 | juice
# 9906 | carrot
# 9906 | oil
# 9906 | broth
# 9906 | basil
# 9906 | oregano
# 9907 | barley
# 9907 | water
# 9907 | salt
# 9907 | onion
# 9907 | celery
# 9907 | soup
# 9907 | carrot
# 9907 | oil
# 9907 | milk
# 9907 | broth
# 9907 | garlic
# 9907 | mushrooms
# 9907 | peppercorns
# 9908 | tomato
# 9908 | tomatoes
# 9908 | barley
# 9908 | macaroni
# 9908 | corn
# 9908 | onion
# 9908 | butter
# 9908 | broccoli
# 9908 | drumsticks
# 9909 | salt
# 9909 | parsley
# 9909 | pepper
# 9909 | oysters
# 9909 | wine
# 9909 | cream
# 9909 | garlic
# 9909 | milk
# 9909 | butter
# 9910 | redhot
# 9910 | margarine
# 9910 | cloves
# 9910 | wing
# 9910 | mix
# 9910 | basil
# 9910 | juice
# 9910 | oil
# 9911 | worcestershire
# 9911 | vinegar
# 9911 | butter
# 9911 | pepper
# 9911 | redhot
# 9911 | salt
# 9912 | cheese
# 9912 | half
# 9912 | flour
# 9912 | broth
# 9912 | soup
# 9912 | celery
# 9912 | onion
# 9912 | water
# 9912 | pepper
# 9912 | sauce
# 9912 | butter
# 9912 | chicken
# 9913 | barley
# 9913 | thighs
# 9913 | leaves
# 9913 | poultry
# 9913 | onion
# 9913 | juice
# 9913 | salt
# 9913 | carrots
# 9913 | water
# 9913 | pepper
# 9913 | sage
# 9913 | bouillon
# 9914 | bacon
# 9914 | cheese
# 9914 | thighs
# 9914 | soup
# 9915 | broth
# 9915 | cilantro
# 9915 | corn
# 9915 | cheese
# 9915 | chips
# 9915 | mix
# 9915 | tomato
# 9915 | beans
# 9915 | cream
# 9915 | tomatoes
# 9915 | thighs
# 9915 | chiles
# 9916 | cheese
# 9916 | olives
# 9916 | cloves
# 9916 | cream
# 9916 | thighs
# 9916 | pepper
# 9916 | chives
# 9916 | soup
# 9916 | tortillas
# 9916 | peppers
# 9917 | fat
# 9917 | salt
# 9917 | flakes
# 9917 | chunks
# 9917 | carrots
# 9917 | soup
# 9918 | tomatoes
# 9918 | cube
# 9918 | spinach
# 9918 | bite
# 9918 | oil
# 9918 | paste
# 9918 | chickpeas
# 9919 | garlic
# 9919 | oil
# 9919 | sugar
# 9919 | sauce
# 9919 | pepper
# 9919 | onion
# 9920 | poultry
# 9920 | halves
# 9920 | ounces
# 9920 | soup
# 9921 | pepper
# 9921 | butter
# 9921 | cloves
# 9921 | halves
# 9921 | water
# 9921 | soup
# 9921 | sage
# 9921 | onion
# 9921 | crumbs
# 9921 | livers
# 9921 | salt
# 9921 | broth
# 9922 | butter
# 9922 | water
# 9922 | crumbs
# 9922 | soup
# 9922 | breasts
# 9922 | cheese
# 9923 | wine
# 9923 | cream
# 9923 | rosemary
# 9923 | butter
# 9923 | halves
# 9923 | pepper
# 9923 | thyme
# 9923 | pasta
# 9923 | soup
# 9923 | mushrooms
# 9924 | cheese
# 9924 | soup
# 9924 | halves
# 9924 | milk
# 9924 | triangles
# 9924 | pepper
# 9925 | celery
# 9925 | meat
# 9925 | soup
# 9925 | eggs
# 9925 | cornbread
# 9925 | butter
# 9925 | bread
# 9925 | pepper
# 9925 | onions
# 9925 | broth
# 9925 | poultry
# 9926 | onion
# 9926 | strips
# 9926 | cumin
# 9926 | cilantro
# 9926 | corn
# 9926 | rotel
# 9926 | sauce
# 9926 | breasts
# 9926 | cream
# 9926 | tomato
# 9926 | pepper
# 9926 | broth
# 9926 | cheese
# 9926 | salt
# 9927 | broth
# 9927 | miso
# 9927 | cloves
# 9927 | kale
# 9927 | oil
# 9927 | onions
# 9927 | water
# 9927 | carrots
# 9927 | quinoa
# 9927 | mushrooms
# 9927 | tofu
# 9927 | onion
# 9927 | pepper
# 9927 | turmeric
# 9928 | wine
# 9928 | breasts
# 9928 | butter
# 9928 | cheese
# 9928 | mix
# 9928 | soup
# 9929 | minute
# 9929 | water
# 9929 | celery
# 9929 | soup
# 9929 | breasts
# 9929 | onions
# 9929 | florets
# 9929 | butter
# 9929 | whiz
# 9930 | pepper
# 9930 | celery
# 9930 | cheese
# 9930 | sauce
# 9930 | potatoes
# 9930 | broth
# 9930 | carrots
# 9930 | milk
# 9930 | parsley
# 9930 | onion
# 9931 | velveeta
# 9931 | florets
# 9931 | soup
# 9931 | cheese
# 9932 | potatoes
# 9932 | beans
# 9932 | puree
# 9932 | basil
# 9932 | cheese
# 9932 | carrot
# 9932 | leaves
# 9932 | water
# 9932 | soy
# 9932 | oil
# 9932 | kernels
# 9932 | pepper
# 9932 | onion
# 9933 | cream
# 9933 | water
# 9933 | herbs
# 9933 | onion
# 9933 | beef
# 9933 | soup
# 9933 | pasta
# 9934 | macaroni
# 9934 | peppers
# 9934 | celery
# 9934 | mix
# 9934 | mayonnaise
# 9934 | pepper
# 9934 | onions
# 9934 | oil
# 9935 | garlic
# 9935 | cheese
# 9935 | spaghetti
# 9935 | water
# 9935 | onion
# 9935 | beef
# 9935 | soup
# 9935 | pepper
# 9936 | water
# 9936 | spaghetti
# 9936 | soup
# 9936 | tomato
# 9936 | onion
# 9936 | beef
# 9937 | pounds
# 9937 | seasoning
# 9937 | spaghetti
# 9937 | soup
# 9937 | tomatoes
# 9937 | cheese
# 9937 | flakes
# 9937 | oil
# 9938 | spaghetti
# 9938 | mix
# 9938 | beef
# 9938 | paprika
# 9938 | soup
# 9938 | onion
# 9938 | velveeta
# 9938 | broth
# 9938 | oil
# 9938 | rotel
# 9938 | cheese
# 9938 | water
# 9939 | pasta
# 9939 | pepper
# 9939 | leaves
# 9939 | cloves
# 9939 | onion
# 9939 | flakes
# 9939 | sausage
# 9939 | tomatoes
# 9939 | tomato
# 9939 | oil
# 9939 | stock
# 9940 | butter
# 9940 | garlic
# 9940 | pepper
# 9940 | parsley
# 9940 | onion
# 9940 | egg
# 9940 | noodles
# 9940 | pork
# 9940 | escarole
# 9940 | cheese
# 9940 | oil
# 9940 | halves
# 9940 | cornstarch
# 9940 | crumbs
# 9940 | broth
# 9940 | carrots
# 9941 | oil
# 9941 | onions
# 9941 | chestnuts
# 9941 | vinegar
# 9941 | sugar
# 9941 | wine
# 9941 | paste
# 9941 | peanuts
# 9941 | garlic
# 9941 | chunks
# 9941 | sauce
# 9941 | water
# 9942 | broth
# 9942 | quinoa
# 9942 | cumin
# 9942 | strips
# 9942 | paprika
# 9942 | tomatoes
# 9942 | salt
# 9942 | rice
# 9942 | oil
# 9942 | corn
# 9942 | onion
# 9942 | pepper
# 9942 | breast
# 9943 | egg
# 9943 | flour
# 9943 | potatoes
# 9943 | croutons
# 9944 | broth
# 9944 | potatoes
# 9944 | sauce
# 9944 | paprika
# 9944 | pepper
# 9944 | half
# 9944 | onion
# 9944 | corn
# 9944 | bacon
# 9944 | dash
# 9945 | broth
# 9945 | onion
# 9945 | potatoes
# 9945 | butter
# 9945 | milk
# 9946 | half
# 9946 | cheese
# 9946 | basil
# 9946 | thyme
# 9946 | flakes
# 9946 | onion
# 9946 | potatoes
# 9946 | onions
# 9946 | pepper
# 9946 | flour
# 9946 | water
# 9946 | salt
# 9946 | cornstarch
# 9946 | stock
# 9946 | bacon
# 9947 | butter
# 9947 | flour
# 9947 | cream
# 9947 | potatoes
# 9947 | milk
# 9948 | water
# 9948 | milk
# 9948 | potatoes
# 9948 | pepper
# 9948 | butter
# 9949 | potatoes
# 9949 | pepper
# 9949 | onions
# 9949 | butter
# 9949 | cheese
# 9949 | salt
# 9949 | cream
# 9949 | milk
# 9949 | bits
# 9949 | flour
# 9950 | bacon
# 9950 | cubes
# 9950 | half
# 9950 | chives
# 9950 | cheese
# 9950 | salt
# 9950 | cream
# 9950 | pepper
# 9950 | butter
# 9950 | broth
# 9950 | onion
# 9951 | broth
# 9951 | cheese
# 9951 | potatoes
# 9951 | cream
# 9951 | bacon
# 9951 | butter
# 9951 | pepper
# 9951 | greens
# 9951 | salt
# 9951 | onion
# 9952 | cream
# 9952 | potatoes
# 9952 | bacon
# 9952 | velveeta
# 9952 | pepper
# 9952 | salt
# 9952 | milk
# 9952 | cheese
# 9953 | pepper
# 9953 | broth
# 9953 | potatoes
# 9953 | ginger
# 9953 | milk
# 9953 | pumpkin
# 9953 | salt
# 9953 | lime
# 9954 | bacon
# 9954 | half
# 9954 | flour
# 9954 | cloves
# 9954 | onion
# 9954 | butter
# 9954 | pepper
# 9954 | broth
# 9954 | cream
# 9954 | eighths
# 9954 | cheese
# 9954 | parsley
# 9954 | salt
# 9955 | milk
# 9955 | onion
# 9955 | salt
# 9955 | cream
# 9955 | paprika
# 9955 | weed
# 9955 | potatoes
# 9955 | cheese
# 9955 | soup
# 9955 | pepper
# 9956 | cloves
# 9956 | salt
# 9956 | flour
# 9956 | milk
# 9956 | carrot
# 9956 | pepper
# 9956 | cheese
# 9956 | bacon
# 9956 | parsley
# 9956 | broth
# 9956 | corn
# 9956 | onion
# 9956 | celery
# 9956 | butter
# 9956 | potatoes
# 9956 | eggs
# 9957 | oil
# 9957 | potatoes
# 9957 | mix
# 9958 | soup
# 9958 | onion
# 9958 | beef
# 9958 | potatoes
# 9958 | mix
# 9958 | carrots
# 9959 | oil
# 9959 | mix
# 9959 | pepper
# 9959 | steaks
# 9959 | onion
# 9959 | soup
# 9959 | ounce
# 9959 | sauce
# 9959 | mushrooms
# 9960 | loin
# 9960 | onion
# 9960 | soup
# 9960 | pepper
# 9960 | oil
# 9960 | apple
# 9960 | cranberries
# 9960 | ounce
# 9961 | onions
# 9961 | mix
# 9961 | chops
# 9961 | potatoes
# 9961 | broth
# 9961 | pepper
# 9961 | carrots
# 9962 | onion
# 9962 | cloves
# 9962 | cumin
# 9962 | tofu
# 9962 | chickpeas
# 9962 | ginger
# 9962 | peppers
# 9962 | paste
# 9962 | scallions
# 9962 | sauce
# 9962 | carrots
# 9962 | kale
# 9962 | curry
# 9962 | oil
# 9962 | salt
# 9962 | broth
# 9962 | ounce
# 9963 | patties
# 9963 | tomato
# 9963 | kale
# 9963 | onion
# 9963 | pepper
# 9963 | cubes
# 9963 | stock
# 9963 | juice
# 9963 | sazon
# 9963 | oil
# 9963 | adobo
# 9964 | sugar
# 9964 | redhot
# 9964 | hellmann
# 9964 | vinegar
# 9965 | sugar
# 9965 | flour
# 9965 | oil
# 9965 | eggs
# 9965 | soda
# 9965 | buttermilk
# 9966 | buttermilk
# 9966 | cream
# 9967 | tomatoes
# 9967 | onion
# 9967 | bread
# 9967 | basil
# 9967 | cucumber
# 9967 | garlic
# 9967 | oil
# 9967 | vinegar
# 9967 | thyme
# 9968 | cheese
# 9968 | honey
# 9968 | oil
# 9968 | onion
# 9968 | strawberries
# 9968 | pepper
# 9968 | cubes
# 9968 | salt
# 9968 | tomatoes
# 9968 | vinegar
# 9969 | mint
# 9969 | bread
# 9969 | tomato
# 9969 | lettuce
# 9969 | onions
# 9969 | parsley
# 9969 | cloves
# 9969 | cucumber
# 9969 | pepper
# 9969 | radishes
# 9970 | butter
# 9970 | bread
# 9970 | potatoes
# 9971 | cream
# 9971 | onion
# 9971 | tomatoes
# 9971 | pepper
# 9971 | chives
# 9971 | garlic
# 9971 | oil
# 9971 | yogurt
# 9971 | bread
# 9972 | leaves
# 9972 | olives
# 9972 | vinegar
# 9972 | pepper
# 9972 | size
# 9972 | oil
# 9972 | wedges
# 9972 | onion
# 9973 | oil
# 9973 | salt
# 9973 | size
# 9973 | vinegar
# 9973 | pepper
# 9973 | tomatoes
# 9973 | cucumber
# 9973 | onion
# 9973 | cheese
# 9973 | basil
# 9974 | tomato
# 9974 | mayonnaise
# 9974 | bread
# 9974 | mustard
# 9974 | pesto
# 9974 | lettuce
# 9974 | water
# 9974 | cloves
# 9975 | pepper
# 9975 | cheese
# 9975 | cloves
# 9975 | oil
# 9975 | vinegar
# 9976 | ham
# 9976 | pepper
# 9976 | relish
# 9976 | mayonnaise
# 9976 | onion
# 9976 | celery
# 9976 | salt
# 9977 | peppers
# 9977 | flour
# 9977 | beer
# 9977 | sugar
# 9977 | butter
# 9977 | cheese
# 9978 | sugar
# 9978 | flakes
# 9978 | cloves
# 9978 | noodles
# 9978 | peanuts
# 9978 | vinegar
# 9978 | oil
# 9978 | carrot
# 9978 | cilantro
# 9978 | lime
# 9978 | sauce
# 9979 | onions
# 9979 | peas
# 9979 | seeds
# 9979 | meat
# 9979 | pasta
# 9979 | chestnuts
# 9979 | sauce
# 9979 | vinegar
# 9979 | oil
# 9979 | choy
# 9979 | nuts
# 9979 | sugar
# 9979 | juice
# 9979 | butter
# 9980 | oil
# 9980 | seeds
# 9980 | onion
# 9980 | pepper
# 9980 | pasta
# 9980 | sugar
# 9980 | vinegar
# 9980 | sauce
# 9981 | soy
# 9981 | carrots
# 9981 | flakes
# 9981 | oil
# 9981 | seeds
# 9981 | matchsticks
# 9981 | sugar
# 9981 | salt
# 9981 | juice
# 9981 | noodles
# 9981 | ketchup
# 9981 | onion
# 9982 | oil
# 9982 | seeds
# 9982 | noodles
# 9982 | vinegar
# 9982 | mix
# 9982 | sugar
# 9982 | onions
# 9982 | peanuts
# 9983 | packets
# 9983 | seeds
# 9983 | almonds
# 9983 | onions
# 9983 | mix
# 9984 | vinegar
# 9984 | salt
# 9984 | garlic
# 9984 | sugar
# 9984 | cucumbers
# 9984 | ginger
# 9984 | water
# 9984 | noodles
# 9984 | pepper
# 9984 | shallot
# 9984 | sauce
# 9985 | oil
# 9985 | almonds
# 9985 | sugar
# 9985 | sauce
# 9985 | seeds
# 9985 | vinegar
# 9985 | cabbage
# 9985 | noodles
# 9986 | sauce
# 9986 | cilantro
# 9986 | mint
# 9986 | peanuts
# 9986 | sugar
# 9986 | vinegar
# 9986 | pepper
# 9986 | breast
# 9986 | carrots
# 9986 | oil
# 9986 | onions
# 9986 | spaghetti
# 9986 | basil
# 9986 | garlic
# 9987 | pepper
# 9987 | mustard
# 9987 | paprika
# 9987 | vinegar
# 9987 | sugar
# 9987 | sauce
# 9987 | mayonnaise
# 9987 | worcestershire
# 9988 | sugar
# 9988 | segments
# 9988 | noodles
# 9988 | oil
# 9988 | vinegar
# 9988 | almonds
# 9988 | lettuce
# 9989 | sugar
# 9989 | mix
# 9989 | onions
# 9989 | oil
# 9989 | water
# 9989 | kernels
# 9989 | vinegar
# 9989 | packets
# 9989 | cashews
# 9990 | tomatoes
# 9990 | juice
# 9990 | spears
# 9990 | salt
# 9990 | oil
# 9990 | garlic
# 9991 | seeds
# 9991 | cranberries
# 9991 | lemon
# 9991 | cheese
# 9991 | salt
# 9991 | tomatoes
# 9991 | kale
# 9991 | oil
# 9992 | pepper
# 9992 | nuts
# 9992 | vinegar
# 9992 | onions
# 9992 | tomatoes
# 9992 | olives
# 9992 | sugar
# 9992 | oil
# 9993 | cheese
# 9993 | tomatoes
# 9993 | nectarines
# 9993 | basil
# 9994 | vinegar
# 9994 | tomatoes
# 9994 | sugar
# 9994 | basil
# 9994 | parsley
# 9994 | salt
# 9994 | oil
# 9995 | tomatoes
# 9995 | cheese
# 9995 | strips
# 9995 | pepper
# 9995 | oil
# 9996 | tomatoes
# 9996 | onion
# 9996 | pepper
# 9996 | vinaigrette
# 9996 | avocados
# 9997 | garlic
# 9997 | parsley
# 9997 | onion
# 9997 | tomatoes
# 9997 | pepper
# 9997 | cucumber
# 9997 | vinegar
# 9997 | basil
# 9998 | chunks
# 9998 | cucumber
# 9998 | mayonnaise
# 9998 | onion
# 9998 | cloves
# 9998 | pepper
# 9998 | salt
# 9999 | pepper
# 9999 | oil
# 9999 | leaves
# 9999 | tomatoes
# 9999 | vinegar
# 10000 | pepper
# 10000 | basil
# 10000 | avocados
# 10000 | sugar
# 10000 | tomatoes
# 10000 | cheese
# 10000 | vinegar
# 10001 | zucchini
# 10001 | onion
# 10001 | sugar
# 10001 | cucumbers
# 10001 | pepper
# 10001 | lemon
# 10001 | vinegar
# 10001 | basil
# 10001 | leaves
# 10001 | salt
# 10001 | zest
# 10001 | olives
# 10001 | tomatoes
# 10001 | oil
# 10002 | vinegar
# 10002 | quinoa
# 10002 | cheese
# 10002 | oil
# 10002 | tomatoes
# 10002 | lemon
# 10002 | broth
# 10002 | parsley
# 10002 | olives
# 10002 | cloves
# 10002 | onion
# 10002 | pepper
# Ingredient extraction complete. Data saved to 'Question1_B.csv'.

# %% [markdown]
# **Question 1: Part (C)**
#
# In this solution, we accomplish the task of storing recipe and ingredient information in the specified format:
#
# 1. **Load the Extracted Ingredients Data**:
#    - **Code**: `df = pd.read_csv('Question1_B.csv')`
#    - **Explanation**: We start by loading the CSV file (`Question1_B.csv`) that contains the recipe IDs and corresponding ingredient names into a Pandas DataFrame. This file was previously generated and contains the necessary data for this task.
#
# 2. **Randomly Choose 100 Unique Recipe IDs**:
#    - **Code**:
#      ```python
#      unique_recipe_ids = df['Recipe ID'].unique()
#      selected_recipe_ids = random.sample(list(unique_recipe_ids), 100)
#      ```
#    - **Explanation**: We extract all unique recipe IDs from the DataFrame and then use the `random.sample()` function to randomly select 100 of these recipe IDs. This ensures that our sample is representative and unbiased.
#
# 3. **Filter the DataFrame for Selected Recipe IDs**:
#    - **Code**: `filtered_df = df[df['Recipe ID'].isin(selected_recipe_ids)]`
#    - **Explanation**: We filter the original DataFrame to include only the rows where the 'Recipe ID' matches one of the 100 randomly selected IDs. This gives us a subset of the data relevant to our selected recipes.
#
# 4. **Save the Recipe and Ingredient Information to a Text File**:
#    - **Code**:
#      ```python
#      with open('Question1_C.txt', 'w') as file:
#          for recipe_id in selected_recipe_ids:
#              # Filter ingredients for the current Recipe ID
#              ingredients = filtered_df[filtered_df['Recipe ID'] == recipe_id]
#              for _, row in ingredients.iterrows():
#                  file.write(f"{row['Recipe ID']}—{row['Ingredient']}\n")
#              file.write("\n")
#      ```
#    - **Explanation**: We open a text file (`Question1_C.txt`) for writing. For each selected recipe ID, we filter the DataFrame to get the ingredients associated with that ID. We then write each recipe ID and ingredient pair to the file in the format `(Recipe ID)—(Ingredient Name)`. After writing all ingredients for a recipe, we add a newline for separation between different recipes.
#
# This approach ensures that the data is stored in a clear and structured format, making it easy to review and analyze the recipe and ingredient information.

# %%
import pandas as pd
import random

# Load the extracted ingredients CSV file
df = pd.read_csv('Question1_B.csv')

# Randomly choose 100 unique recipe IDs
unique_recipe_ids = df['Recipe ID'].unique()
selected_recipe_ids = random.sample(list(unique_recipe_ids), 100)

# Filter the DataFrame for these selected Recipe IDs
filtered_df = df[df['Recipe ID'].isin(selected_recipe_ids)]

# Save the selected recipes and ingredients to a text file
with open('Question1_C.txt', 'w') as file:
    for recipe_id in selected_recipe_ids:
        # Filter ingredients for the current Recipe ID
        ingredients = filtered_df[filtered_df['Recipe ID'] == recipe_id]
        for _, row in ingredients.iterrows():
            file.write(f"{row['Recipe ID']}—{row['Ingredient']}\n")
        file.write("\n")

print("Selected recipes and ingredients saved to 'Question1_C.txt'.")
# Out:
# Selected recipes and ingredients saved to 'Question1_C.txt'.
